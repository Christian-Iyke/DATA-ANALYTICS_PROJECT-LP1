# %%
import pandas as pd

import numpy as np

startup_2021 = pd.read_csv(r'C:\Users\User\Desktop\AZUBI AFRICA\Projects\LP 1\startup_funding2021.csv')

startup_2021
# Out:
#        Company/Brand  Founded HeadQuarter                 Sector  \
# 0     Unbox Robotics   2019.0   Bangalore             AI startup
# 1             upGrad   2015.0      Mumbai                 EdTech
# 2        Lead School   2012.0      Mumbai                 EdTech
# 3            Bizongo   2015.0      Mumbai         B2B E-commerce
# 4           FypMoney   2021.0    Gurugram                FinTech
# ...              ...      ...         ...                    ...
# 1204        Gigforce   2019.0    Gurugram  Staffing & Recruiting
# 1205          Vahdam   2015.0   New Delhi       Food & Beverages
# 1206    Leap Finance   2019.0   Bangalore     Financial Services
# 1207    CollegeDekho   2015.0    Gurugram                 EdTech
# 1208          WeRize   2019.0   Bangalore     Financial Services
#
#                                            What it does  \
# 0     Unbox Robotics builds on-demand AI-driven ware...
# 1        UpGrad is an online higher education platform.
# ...

# %%
# STARTUP_2021 PROCESSING

startup_2021.head(100)
# Out:
#      Company/Brand  Founded     HeadQuarter                    Sector  \
# 0   Unbox Robotics   2019.0       Bangalore                AI startup
# 1           upGrad   2015.0          Mumbai                    EdTech
# 2      Lead School   2012.0          Mumbai                    EdTech
# 3          Bizongo   2015.0          Mumbai            B2B E-commerce
# 4         FypMoney   2021.0        Gurugram                   FinTech
# ..             ...      ...             ...                       ...
# 95     TartanSense   2015.0       Bangalore    Information Technology
# 96        Bewakoof   2012.0          Mumbai         Apparel & Fashion
# 97       Kirana247   2018.0       New Delhi  Logistics & Supply Chain
# 98         FanPlay   2020.0  Computer Games            Computer Games
# 99         NeoDocs   2020.0          Mumbai                Healthtech
#
#                                          What it does  \
# 0   Unbox Robotics builds on-demand AI-driven ware...
# ...

# %%
startup_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1209 entries, 0 to 1208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  1209 non-null   object
#  1   Founded        1208 non-null   float64
#  2   HeadQuarter    1208 non-null   object
#  3   Sector         1209 non-null   object
#  4   What it does   1209 non-null   object
#  5   Founders       1205 non-null   object
#  6   Investor       1147 non-null   object
#  7   Amount($)      1206 non-null   object
#  8   Stage          781 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 85.1+ KB

# %%
startup_2021.isnull().sum()
# Out:
# Company/Brand      0
# Founded            1
# HeadQuarter        1
# Sector             0
# What it does       0
# Founders           4
# Investor          62
# Amount($)          3
# Stage            428
# dtype: int64

# %%
# COLUMN BY COLUMN CLEANING

# FOUNDED COLUMN CLEANING


# CHECKING FOR MISSING VALUES
startup_2021['Founded'].isna().sum()
# Out:
# 1

# %% [markdown]
# ### the Founded Column has only 1 nan value. We can use the mean or the mode to fill it

# %%
startup_2021['Founded'].unique()
# Out:
# array([2019., 2015., 2012., 2021., 2014., 2018., 2016., 2020., 2010.,
#        2017., 1993., 2008., 2013., 1999., 1989., 2011.,   nan, 2009.,
#        2002., 1994., 2006., 2000., 2007., 1978., 2003., 1998., 1991.,
#        1984., 2004., 2005., 1963.])

# %%
# SETTING THE DATATYPE FOR THE FOUNDED COLUMN TO STRING

startup_2021['Founded'] = startup_2021['Founded'].replace(np.nan, 0)

startup_2021['Founded'] = startup_2021['Founded'].astype(int)

startup_2021['Founded']
# Out:
# 0       2019
# 1       2015
# 2       2012
# 3       2015
# 4       2021
#         ...
# 1204    2019
# 1205    2015
# 1206    2019
# 1207    2015
# 1208    2019
# Name: Founded, Length: 1209, dtype: int32

# %%
# We are filling the "NAN" with the mean 

# calculating the mean and repalcing "0" with it

mean_val = startup_2021['Founded'].mean()

mean_val
# Out:
# 2014.987593052109

# %%
startup_2021.Founded = startup_2021.Founded.replace("0",2015)

startup_2021.Founded
# Out:
# 0       2019
# 1       2015
# 2       2012
# 3       2015
# 4       2021
#         ...
# 1204    2019
# 1205    2015
# 1206    2019
# 1207    2015
# 1208    2019
# Name: Founded, Length: 1209, dtype: int32

# %%
startup_2021.Founded.isna().sum()
# Out:
# 0

# %% [markdown]
# ### Our Founded Column is clean now.

# %%
# CLEANING OF THE HEADQUARTERS COLUMN

startup_2021['HeadQuarter'].unique()
# Out:
# array(['Bangalore', 'Mumbai', 'Gurugram', 'New Delhi', 'Hyderabad',
#        'Jaipur', 'Ahmadabad', 'Chennai', nan,
#        'Small Towns, Andhra Pradesh', 'Goa', 'Rajsamand', 'Ranchi',
#        'Faridabad, Haryana', 'Gujarat', 'Pune', 'Thane', 'Computer Games',
#        'Cochin', 'Noida', 'Chandigarh', 'Gurgaon', 'Vadodara',
#        'Food & Beverages', 'Pharmaceuticals\t#REF!', 'Gurugram\t#REF!',
#        'Kolkata', 'Ahmedabad', 'Mohali', 'Haryana', 'Indore', 'Powai',
#        'Ghaziabad', 'Nagpur', 'West Bengal', 'Patna', 'Samsitpur',
#        'Lucknow', 'Telangana', 'Silvassa', 'Thiruvananthapuram',
#        'Faridabad', 'Roorkee', 'Ambernath', 'Panchkula', 'Surat',
#        'Coimbatore', 'Andheri', 'Mangalore', 'Telugana', 'Bhubaneswar',
#        'Kottayam', 'Beijing', 'Panaji', 'Satara', 'Orissia', 'Jodhpur',
#        'New York', 'Santra', 'Mountain View, CA', 'Trivandrum',
#        'Jharkhand', 'Kanpur', 'Bhilwara', 'Guwahati',
# ...

# %%
# checking the missing value

startup_2021['HeadQuarter'].isna().sum()
# Out:
# 1

# %% [markdown]
# ### It has only one missing value

# %%
# Replacing NAN values with "Undefined"

headquarters_2021 = startup_2021.HeadQuarter.isnull()

headquarters_2021
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1204    False
# 1205    False
# 1206    False
# 1207    False
# 1208    False
# Name: HeadQuarter, Length: 1209, dtype: bool

# %%
# Replacing the 'NAN' value with Keyword "Undefined"

for i in range(len(headquarters_2021)):
    if headquarters_2021[i] == True:
        startup_2021.HeadQuarter[i] = "Undefined"
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15068\4004753485.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   startup_2021.HeadQuarter[i] = "Undefined"

# %%
startup_2021.HeadQuarter.isnull().sum()
# Out:
# 0

# %%
startup_2021['HeadQuarter'] = startup_2021['HeadQuarter'].str.replace('Pharmaceuticals\t#REF!', 'Pharmaceuticals')

startup_2021['HeadQuarter'] = startup_2021['HeadQuarter'].str.replace('Gurugram\t#REF!', 'Gurugram')

startup_2021['HeadQuarter'] = startup_2021['HeadQuarter'].str.replace('Online Media\t#REF!', 'Online Media')


startup_2021
# Out:
#        Company/Brand  Founded HeadQuarter                 Sector  \
# 0     Unbox Robotics     2019   Bangalore             AI startup
# 1             upGrad     2015      Mumbai                 EdTech
# 2        Lead School     2012      Mumbai                 EdTech
# 3            Bizongo     2015      Mumbai         B2B E-commerce
# 4           FypMoney     2021    Gurugram                FinTech
# ...              ...      ...         ...                    ...
# 1204        Gigforce     2019    Gurugram  Staffing & Recruiting
# 1205          Vahdam     2015   New Delhi       Food & Beverages
# 1206    Leap Finance     2019   Bangalore     Financial Services
# 1207    CollegeDekho     2015    Gurugram                 EdTech
# 1208          WeRize     2019   Bangalore     Financial Services
#
#                                            What it does  \
# 0     Unbox Robotics builds on-demand AI-driven ware...
# 1        UpGrad is an online higher education platform.
# ...

# %%
startup_2021.isna().sum()
# Out:
# Company/Brand      0
# Founded            0
# HeadQuarter        0
# Sector             0
# What it does       0
# Founders           4
# Investor          62
# Amount($)          3
# Stage            428
# dtype: int64

# %% [markdown]
# ### Now, the Headquarters Column is great.
#
#
# ## LET'S LOOK AT THE FOUNDERS COLUMN TO CLEAN IT

# %%
# checking for missing values

startup_2021['Founders'].isna().sum()
# Out:
# 4

# %%
# It has only 4 missing values

# We are going to replace them with Keyword "Undefined"

startup_2021['Founders'].unique()
# Out:
# array(['Pramod Ghadge, Shahid Memon',
#        'Mayank Kumar, Phalgun Kompalli, Ravijot Chugh, Ronnie Screwvala',
#        'Smita Deorah, Sumeet Mehta', ..., 'Bala Sarda',
#        'Arnav Kumar, Vaibhav Singh', 'Vishal Chopra, Himanshu Gupta'],
#       dtype=object)

# %%
founders_2021 = startup_2021.Founders.isnull()

founders_2021
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1204    False
# 1205    False
# 1206    False
# 1207    False
# 1208    False
# Name: Founders, Length: 1209, dtype: bool

# %%
# Replacing the '...' value with Keyword "Undefined"

for i in range(len(founders_2021)):
    if founders_2021[i] == True:
        startup_2021.Founders[i] = "Undefined"
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15068\2680666504.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   startup_2021.Founders[i] = "Undefined"

# %%
startup_2021.Founders.isnull().sum()
# Out:
# 0

# %% [markdown]
# ### The Founder column is Cleaned now
#
#
# # CLEANING OF THE INVESTOR COLUMN

# %%
startup_2021.Investor.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1209 entries, 0 to 1208
# Series name: Investor
# Non-Null Count  Dtype
# --------------  -----
# 1147 non-null   object
# dtypes: object(1)
# memory usage: 9.6+ KB

# %%
investors_2021 = startup_2021.Investor.isna().sum()

investors_2021
# Out:
# 62

# %%
startup_2021.Investor.unique()
# Out:
# array(['BEENEXT, Entrepreneur First',
#        'Unilazer Ventures, IIFL Asset Management',
#        'GSV Ventures, Westbridge Capital', 'CDC Group, IDG Capital',
#        'Liberatha Kallat, Mukesh Yadav, Dinesh Nagpal', 'Vy Capital',
#        'CIIE.CO, KIIT-TBI', 'Inflection Point Ventures',
#        'Inflexor Ventures', nan,
#        '9Unicorns Accelerator Fund, Metaform Ventures',
#        'SucSEED Indovation, IIM Calcutta Innovation Park',
#        'Safe Planet Medicare', 'Impact Partners, C4D Partners',
#        'Tiger Global Management, InnoVen Capital', 'Novo Tellus Capital',
#        'Raintree Family Office, ADB arm',
#        'Mumbai Angels, Narendra Shyamsukha', 'Paradigm, Kunal Shah',
#        'Matrix Partners India, GIC', 'Chiratae Ventures, JAFCO Asia',
#        'Mumbai Angels Network, Expert DOJO', 'GVFL',
#        'Kotak Mahindra Bank, FMO', 'Kalaari Capital',
#        'NB Ventures, IAN Fund',
#        'Sequoia Capital India, Hummingbird Ventures',
# ...

# %%
# Replacing the 'missing' values with Keyword "Unknown"

startup_2021['Investor'] = startup_2021['Investor'].apply(str)

#for i in range(investors_2021):
    #if investors_2021[i] == True:
        #startup_2021.Investor[i] = "unknown"

# %%
startup_2021.isna().sum()
# Out:
# Company/Brand      0
# Founded            0
# HeadQuarter        0
# Sector             0
# What it does       0
# Founders           0
# Investor           0
# Amount($)          3
# Stage            428
# dtype: int64

# %% [markdown]
# ### CLEANING OF THE AMOUNT COLUMN

# %%
startup_2021['Amount($)'].isna().sum()
# Out:
# 3

# %%
startup_2021['Amount($)'].unique()
# Out:
# array(['$1,200,000', '$120,000,000', '$30,000,000', '$51,000,000',
#        '$2,000,000', '$188,000,000', '$200,000', 'Undisclosed',
#        '$1,000,000', '$3,000,000', '$100,000', '$700,000', '$9,000,000',
#        '$40,000,000', '$49,000,000', '$400,000', '$300,000',
#        '$25,000,000', '$160,000,000', '$150,000', '$1,800,000',
#        '$5,000,000', '$850,000', '$53,000,000', '$500,000', '$1,100,000',
#        '$6,000,000', '$800,000', '$10,000,000', '$21,000,000',
#        '$7,500,000', '$26,000,000', '$7,400,000', '$1,500,000',
#        '$600,000', '$800,000,000', '$17,000,000', '$3,500,000',
#        '$15,000,000', '$215,000,000', '$2,500,000', '$350,000,000',
#        '$5,500,000', '$83,000,000', '$110,000,000', '$500,000,000',
#        '$65,000,000', '$150,000,000,000', '$300,000,000', '$2,200,000',
#        '$35,000,000', '$140,000,000', '$4,000,000', '$13,000,000', nan,
#        '$Undisclosed', '$2000000', '$800000', '$6000000', '$2500000',
# ...

# %%
# converting the datatype to string

startup_2021['Amount($)'] = startup_2021['Amount($)'].apply(str)


# Removing the comas and spaces

startup_2021['Amount($)'].replace(',','', inplace = True, regex = True)

startup_2021
# Out:
#        Company/Brand  Founded HeadQuarter                 Sector  \
# 0     Unbox Robotics     2019   Bangalore             AI startup
# 1             upGrad     2015      Mumbai                 EdTech
# 2        Lead School     2012      Mumbai                 EdTech
# 3            Bizongo     2015      Mumbai         B2B E-commerce
# 4           FypMoney     2021    Gurugram                FinTech
# ...              ...      ...         ...                    ...
# 1204        Gigforce     2019    Gurugram  Staffing & Recruiting
# 1205          Vahdam     2015   New Delhi       Food & Beverages
# 1206    Leap Finance     2019   Bangalore     Financial Services
# 1207    CollegeDekho     2015    Gurugram                 EdTech
# 1208          WeRize     2019   Bangalore     Financial Services
#
#                                            What it does  \
# 0     Unbox Robotics builds on-demand AI-driven ware...
# 1        UpGrad is an online higher education platform.
# ...

# %%
startup_2021['Amount($)'].unique()
# Out:
# array(['$1200000', '$120000000', '$30000000', '$51000000', '$2000000',
#        '$188000000', '$200000', 'Undisclosed', '$1000000', '$3000000',
#        '$100000', '$700000', '$9000000', '$40000000', '$49000000',
#        '$400000', '$300000', '$25000000', '$160000000', '$150000',
#        '$1800000', '$5000000', '$850000', '$53000000', '$500000',
#        '$1100000', '$6000000', '$800000', '$10000000', '$21000000',
#        '$7500000', '$26000000', '$7400000', '$1500000', '$600000',
#        '$800000000', '$17000000', '$3500000', '$15000000', '$215000000',
#        '$2500000', '$350000000', '$5500000', '$83000000', '$110000000',
#        '$500000000', '$65000000', '$150000000000', '$300000000',
#        '$2200000', '$35000000', '$140000000', '$4000000', '$13000000',
#        'nan', '$Undisclosed', '$9500000', '$8000000', 'Upsparks',
#        '$12000000', '$1700000', '$150000000', '$100000000', '$225000000',
#        '$6700000', '$1300000', '$20000000', '$250000', '$52000000',
# ...

# %%
startup_2021['Amount($)'] = startup_2021['Amount($)'].replace('Undisclosed','np.nan', regex = True)

startup_2021['Amount($)'] = startup_2021['Amount($)'].replace('$undisclosed','np.nan', regex = True)

startup_2021['Amount($)'] = startup_2021['Amount($)'].replace('$Undisclosed','np.nan', regex = True)

startup_2021['Amount($)'] = startup_2021['Amount($)'].replace('nan','np.nan', regex = True)

startup_2021['Amount($)'] = startup_2021['Amount($)'].replace('Undislosed','np.nan', regex = True)

# %%
startup_2021['Amount($)'].unique()
# Out:
# array(['$1200000', '$120000000', '$30000000', '$51000000', '$2000000',
#        '$188000000', '$200000', 'np.np.nan', '$1000000', '$3000000',
#        '$100000', '$700000', '$9000000', '$40000000', '$49000000',
#        '$400000', '$300000', '$25000000', '$160000000', '$150000',
#        '$1800000', '$5000000', '$850000', '$53000000', '$500000',
#        '$1100000', '$6000000', '$800000', '$10000000', '$21000000',
#        '$7500000', '$26000000', '$7400000', '$1500000', '$600000',
#        '$800000000', '$17000000', '$3500000', '$15000000', '$215000000',
#        '$2500000', '$350000000', '$5500000', '$83000000', '$110000000',
#        '$500000000', '$65000000', '$150000000000', '$300000000',
#        '$2200000', '$35000000', '$140000000', '$4000000', '$13000000',
#        'np.nan', '$np.np.nan', '$9500000', '$8000000', 'Upsparks',
#        '$12000000', '$1700000', '$150000000', '$100000000', '$225000000',
#        '$6700000', '$1300000', '$20000000', '$250000', '$52000000',
# ...

# %%
startup_2021['Amount($)']
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1204     True
# 1205     True
# 1206    False
# 1207     True
# 1208     True
# Name: Amount($), Length: 1209, dtype: bool

# %% [markdown]
# # MANUAL CHECKING AND REARRANGING MISS PLACED COLUMNS

# %%
startup_2021[:100]
# Out:
#      Company/Brand  Founded     HeadQuarter                    Sector  \
# 0   Unbox Robotics     2019       Bangalore                AI startup
# 1           upGrad     2015          Mumbai                    EdTech
# 2      Lead School     2012          Mumbai                    EdTech
# 3          Bizongo     2015          Mumbai            B2B E-commerce
# 4         FypMoney     2021        Gurugram                   FinTech
# ..             ...      ...             ...                       ...
# 95     TartanSense     2015       Bangalore    Information Technology
# 96        Bewakoof     2012          Mumbai         Apparel & Fashion
# 97       Kirana247     2018       New Delhi  Logistics & Supply Chain
# 98         FanPlay     2020  Computer Games            Computer Games
# 99         NeoDocs     2020          Mumbai                Healthtech
#
#                                          What it does  \
# 0   Unbox Robotics builds on-demand AI-driven ware...
# ...

# %%
# There is a missed placed value in index 98 = FanPlay, the Amount Column is interchanged with the Stage Column

startup_2021.loc[startup_2021['Company/Brand'] == 'FanPlay']
# Out:
#     Company/Brand  Founded     HeadQuarter          Sector  \
# 98        FanPlay     2020  Computer Games  Computer Games
# 111       FanPlay     2020  Computer Games  Computer Games
#
#                                           What it does Founders  \
# 98   A real money game app specializing in trivia g...   YC W21
# 111  A real money game app specializing in trivia g...   YC W21
#
#                         Investor Amount($)     Stage
# 98   Pritesh Kumar, Bharat Gupta  Upsparks  $1200000
# 111  Pritesh Kumar, Bharat Gupta  Upsparks  $1200000

# %% [markdown]
# ### From the above, it is obvious that FanPlay has a duplicated row and Amount Column interchanged with the Stage column

# %%
# Dropping the duplicated row

startup_2021.drop([98],axis=0,inplace=True)

# %%
startup_2021.loc[startup_2021['Company/Brand'] == 'FanPlay']
# Out:
#     Company/Brand  Founded     HeadQuarter          Sector  \
# 111       FanPlay     2020  Computer Games  Computer Games
#
#                                           What it does Founders  \
# 111  A real money game app specializing in trivia g...   YC W21
#
#                         Investor Amount($)     Stage
# 111  Pritesh Kumar, Bharat Gupta  Upsparks  $1200000

# %%
# Correcting the miss placed values ie interchanging the amount value with the Stage value

startup_2021.loc[startup_2021['Company/Brand'] == 'FanPlay',['Amount($)','Stage','Investor',]] = [1200000,'Series A','Upsparks']

# %%
# viewing the correction result

startup_2021.loc[startup_2021['Company/Brand'] == 'FanPlay']
# Out:
#     Company/Brand  Founded     HeadQuarter          Sector  \
# 111       FanPlay     2020  Computer Games  Computer Games
#
#                                           What it does Founders  Investor  \
# 111  A real money game app specializing in trivia g...   YC W21  Upsparks
#
#     Amount($)     Stage
# 111   1200000  Series A

# %%
startup_2021[250:300]
# Out:
#             Company/Brand  Founded       HeadQuarter  \
# 251               Enmovil     2015         Hyderabad
# 252         ASQI Advisors     2019            Mumbai
# 253    Insurance Samadhan     2018         New Delhi
# 254       Evenflow Brands     2020            Mumbai
# 255            MasterChow     2020  Food & Beverages
# 256    Fullife Healthcare     2009   Pharmaceuticals
# 257               MoEVing     2021          Gurugram
# 258          Pristyn Care     2018          Gurugram
# 259                  Plix     2018            Mumbai
# 260             Uni Cards     2020         Bangalore
# 261           Practically     2018         Hyderabad
# 262              Nestasia     2018           Kolkata
# 263  Vedic Cosmeceuticals     2002             Noida
# 264                Juspay     2012         Bangalore
# 265              TranZact     2017            Mumbai
# 266              Atomberg     2012            Mumbai
# 267                   Ola     2010         Bangalore
# ...

# %%
# At index 256 and 257, there are miss placed columns in Investor, Amount, Stage, headquarter, Company/Brand

# VIEWING INDEX 256

startup_2021.loc[startup_2021['Company/Brand'] == 'Fullife Healthcare']
# Out:
#           Company/Brand  Founded      HeadQuarter  \
# 242  Fullife Healthcare     2009  Pharmaceuticals
# 256  Fullife Healthcare     2009  Pharmaceuticals
#
#                                                 Sector  What it does  \
# 242  Primary Business is Development and Manufactur...  Varun Khanna
# 256  Primary Business is Development and Manufactur...  Varun Khanna
#
#                                Founders   Investor Amount($) Stage
# 242  Morgan Stanley Private Equity Asia  $22000000  Series C   NaN
# 256  Morgan Stanley Private Equity Asia  $22000000  Series C   NaN

# %%
# Fullife Healthcare has duplicate, so we remove the duplicate row

startup_2021.drop([242],axis=0,inplace=True)

# %%
startup_2021.loc[startup_2021['Company/Brand'] == 'Fullife Healthcare']
# Out:
#           Company/Brand  Founded      HeadQuarter  \
# 256  Fullife Healthcare     2009  Pharmaceuticals
#
#                                                 Sector  What it does  \
# 256  Primary Business is Development and Manufactur...  Varun Khanna
#
#                                Founders   Investor Amount($) Stage
# 256  Morgan Stanley Private Equity Asia  $22000000  Series C   NaN

# %%
# CORRECTING THE MISS PLACED VALUES

startup_2021.loc[startup_2021['Company/Brand'] == 'Fullife Healthcare',['Amount($)','Stage','Investor',
    'Founders','What it does','Sector','HeadQuarter']] = [22000000,'Series C','Morgan Stanley Private Equity Asia','Varun Khanna',
    'Primary Business is Development and Manufactur...','Pharmaceuticals','Mumbai']

# %%
# VIEWING THE CORRECTIONS

startup_2021.loc[startup_2021['Company/Brand'] == 'Fullife Healthcare']
# Out:
#           Company/Brand  Founded HeadQuarter           Sector  \
# 256  Fullife Healthcare     2009      Mumbai  Pharmaceuticals
#
#                                           What it does      Founders  \
# 256  Primary Business is Development and Manufactur...  Varun Khanna
#
#                                Investor Amount($)     Stage
# 256  Morgan Stanley Private Equity Asia  22000000  Series C

# %%
# TREATING INDEX 257

startup_2021.loc[startup_2021['Company/Brand'] == 'MoEVing']
# Out:
#     Company/Brand  Founded HeadQuarter  \
# 257       MoEVing     2021    Gurugram
#
#                                                 Sector  \
# 257  MoEVing is India's only Electric Mobility focu...
#
#                     What it does  \
# 257  Vikash Mishra, Mragank Jain
#
#                                            Founders  Investor Amount($) Stage
# 257  Anshuman Maheshwary, Dr Srihari Raju Kalidindi  $5000000      Seed   NaN

# %%
# DEALING WITH ERROR AT INDEX 257

startup_2021.loc[startup_2021['Company/Brand'] == 'MoEVing',['Amount($)','Stage','Investor','Sector',
    'What it does','Founders']] = [5000000,'Seed','Anshuman Maheshwary, Dr Srihari Raju Kalidindi','Power',
    'MoEVing is Indian only Electric Mobility focu...','Vikash Mishra, Mragank Jain']

# %%
# VIEWING THE CORRECTION

startup_2021.loc[startup_2021['Company/Brand'] == 'MoEVing']
# Out:
#     Company/Brand  Founded HeadQuarter Sector  \
# 257       MoEVing     2021    Gurugram  Power
#
#                                          What it does  \
# 257  MoEVing is Indian only Electric Mobility focu...
#
#                         Founders  \
# 257  Vikash Mishra, Mragank Jain
#
#                                            Investor Amount($) Stage
# 257  Anshuman Maheshwary, Dr Srihari Raju Kalidindi   5000000  Seed

# %%
# AT INDEX 538 THERE IS A MISS PLACED COLUMN

startup_2021.loc[startup_2021['Company/Brand'] == 'Little Leap']
# Out:
#     Company/Brand  Founded HeadQuarter  Sector  \
# 538   Little Leap     2020   New Delhi  EdTech
#
#                             What it does  \
# 538  Soft Skills that make Smart Leaders
#
#                                               Founders      Investor  \
# 538  Holistic Development Programs for children in ...  Vishal Gupta
#
#         Amount($)    Stage
# 538  ah! Ventures  $300000

# %%
# CORRECTING THE MISS PLACED VALUES

startup_2021.loc[startup_2021['Company/Brand'] == 'Little Leap',['Amount($)','Stage','Investor',
    'Founders']] = [300000,'Seed','ah! Ventures','Vishal Gupta']

# %%
# VIEWING THE CORRECTION

startup_2021.loc[startup_2021['Company/Brand'] == 'Little Leap']
# Out:
#     Company/Brand  Founded HeadQuarter  Sector  \
# 538   Little Leap     2020   New Delhi  EdTech
#
#                             What it does      Founders      Investor  \
# 538  Soft Skills that make Smart Leaders  Vishal Gupta  ah! Ventures
#
#     Amount($) Stage
# 538    300000  Seed

# %%
# MISS PLACED COLUMN AT INDEX 551

startup_2021.loc[startup_2021['Company/Brand'] == 'BHyve']
# Out:
#     Company/Brand  Founded HeadQuarter           Sector  \
# 551         BHyve     2020      Mumbai  Human Resources
#
#                                           What it does           Founders  \
# 551  A Future of Work Platform for diffusing Employ...  Backed by 100x.VC
#
#                             Investor                      Amount($)    Stage
# 551  Omkar Pandharkame, Ketaki Ogale  ITO Angel Network LetsVenture  $300000

# %%
# CORRECTING THE MISS PLACED VALUES

startup_2021.loc[startup_2021['Company/Brand'] == 'BHyve',['Amount($)','Stage','Founders','Investor']] = [300000,'np.nan',
 'Omkar Pandharkame, Ketaki Ogale','ITO Angel Network LetsVenture']

# %%
# VIEWING THE CORRECTION

startup_2021.loc[startup_2021['Company/Brand'] == 'BHyve']
# Out:
#     Company/Brand  Founded HeadQuarter           Sector  \
# 551         BHyve     2020      Mumbai  Human Resources
#
#                                           What it does  \
# 551  A Future of Work Platform for diffusing Employ...
#
#                             Founders                       Investor Amount($)  \
# 551  Omkar Pandharkame, Ketaki Ogale  ITO Angel Network LetsVenture    300000
#
#       Stage
# 551  np.nan

# %%
# MISS PLACED COLUMN AT INDEX 1148

startup_2021.loc[startup_2021['Company/Brand'] == 'Godamwale']
# Out:
#      Company/Brand  Founded HeadQuarter                    Sector  \
# 1148     Godamwale     2016      Mumbai  Logistics & Supply Chain
#
#                                            What it does  \
# 1148  Godamwale is tech enabled integrated logistics...
#
#                                        Founders        Investor Amount($)  \
# 1148  Basant Kumar, Vivek Tiwari, Ranbir Nandan  1000000\t#REF!      Seed
#
#      Stage
# 1148   NaN

# %%
# CORRECTING THE MISS PLACED VALUES

startup_2021.loc[startup_2021['Company/Brand'] == 'Godamwale',['Amount($)','Stage','Investor']] = [1000000,'Seed',
 'Unknown']

# %%
# VIEWING THE CORRECTION

startup_2021.loc[startup_2021['Company/Brand'] == 'Godamwale']
# Out:
#      Company/Brand  Founded HeadQuarter                    Sector  \
# 1148     Godamwale     2016      Mumbai  Logistics & Supply Chain
#
#                                            What it does  \
# 1148  Godamwale is tech enabled integrated logistics...
#
#                                        Founders Investor Amount($) Stage
# 1148  Basant Kumar, Vivek Tiwari, Ranbir Nandan  Unknown   1000000  Seed

# %%
# MISS PLACED COLUMN AT INDEX 545

startup_2021.loc[startup_2021['Company/Brand'] == 'AdmitKard']
# Out:
#     Company/Brand  Founded HeadQuarter  Sector  \
# 545     AdmitKard     2016       Noida  EdTech
#
#                                           What it does  \
# 545  A tech solution for end to end career advisory...
#
#                                              Founders  Investor     Amount($)  \
# 545  Vamsi Krishna, Pulkit Jain, Gaurav Munjal\t#REF!  $1000000  Pre-series A
#
#     Stage
# 545   NaN

# %%
# CORRECTING THE MISS PLACED VALUES

startup_2021.loc[startup_2021['Company/Brand'] == 'AdmitKard',['Amount($)','Stage','Investor','Founders']] = [1000000,'Pre-series A',
 'Unknown','Vamsi Krishna, Pulkit Jain, Gaurav Munjal']

# %%
# VIEWING THE CORRECTION


startup_2021.loc[startup_2021['Company/Brand'] == 'AdmitKard']
# Out:
#     Company/Brand  Founded HeadQuarter  Sector  \
# 545     AdmitKard     2016       Noida  EdTech
#
#                                           What it does  \
# 545  A tech solution for end to end career advisory...
#
#                                       Founders Investor Amount($)  \
# 545  Vamsi Krishna, Pulkit Jain, Gaurav Munjal  Unknown   1000000
#
#             Stage
# 545  Pre-series A

# %%
# MISS PLACED COLUMNS AT INDEX 677

startup_2021.loc[startup_2021['Amount($)'] == 'JITO Angel Network LetsVenture']
# Out:
#         Company/Brand  Founded HeadQuarter  Sector  \
# 677  Saarthi Pedagogy     2015   Ahmadabad  EdTech
#
#                                           What it does  Founders  \
# 677  India's fastest growing Pedagogy company, serv...  Pedagogy
#
#            Investor                       Amount($)     Stage
# 677  Sushil Agarwal  JITO Angel Network LetsVenture  $1000000

# %%
# CORRECTING THE MISS PLACED VALUES

startup_2021.loc[startup_2021['Company/Brand'] == 'Saarthi Pedagogy',['Amount($)','Stage']] = [1000000,'Seed']

# %%
# VIEWING THE CORRECTION

startup_2021.loc[startup_2021['Company/Brand'] == 'Saarthi Pedagogy']
# Out:
#         Company/Brand  Founded HeadQuarter  Sector  \
# 677  Saarthi Pedagogy     2015   Ahmadabad  EdTech
#
#                                           What it does  Founders  \
# 677  India's fastest growing Pedagogy company, serv...  Pedagogy
#
#            Investor Amount($) Stage
# 677  Sushil Agarwal   1000000  Seed
