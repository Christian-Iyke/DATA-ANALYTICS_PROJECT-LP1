# %% [markdown]
# ### Data Analysis Project -- Indian Start-up Funding Analysis

# %% [markdown]
# ### BUSINESS UNDERSTANDING
#
# ### Ideas, creativity, and execution are essential for a start-up to flourish. But are they enough? Investors provide start-ups and other entrepreneurial ventures with the capital---popularly known as "funding"---to think big, grow rich, and leave a lasting impact.
#
# ### In this project, you are going to analyse funding received by start-ups in India from 2018 to 2021. You will find the data for each year of funding in a separate csv file in the dataset provided.
#
# ### In these files you'll find the start-ups' details, the funding amounts received, and the investors' information.

# %% [markdown]
# ### Scenario

# %% [markdown]
# ### Your team is trying to venture into the Indian start-up ecosystem. As the data expert of the team you are to investigate the ecosystem and propose the best course of action.

# %% [markdown]
# ### Instructions
#
# ### Your task is to develop a unique story from this dataset by stating and testing a hypothesis,
#
# ### asking questions, perform analysis and share insights with appropriate visualisations.
#
# ### So as part of the project you are to:
#
# ### 1) Ask questions
#
# ### 2) Develop hypothesis
#
# ### 3) Process the data
#
# ### 4) Analyse the data
#
# ### 5) Visualise the data

# %% [markdown]
# ### UNDERSTANDING YOUR DATA

# %% [markdown]
# ### INPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import plotly.express as px
import plotly.graph_objs as go

import seaborn as sns

from scipy import stats
import statistics as stat

from sklearn.impute import SimpleImputer

# %% [markdown]
# ### LOADING DATASETS

# %%
startup_2018= pd.read_csv(r'C:\Users\User\Desktop\AZUBI AFRICA\Projects\LP 1\startup_funding2018.csv')

startup_2018
# Out:
#           Company Name                                           Industry  \
# 0      TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1      Happy Cow Dairy                               Agriculture, Farming
# 2           MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3          PayMe India                        Financial Services, FinTech
# 4             Eunimart                 E-Commerce Platforms, Retail, SaaS
# ..                 ...                                                ...
# 521              Udaan   B2B, Business Development, Internet, Marketplace
# 522  Happyeasygo Group                                    Tourism, Travel
# 523             Mombay         Food and Beverage, Food Delivery, Internet
# 524         Droni Tech                             Information Technology
# 525            Netmeds         Biotechnology, Health Care, Pharmaceutical
#
#     Round/Series       Amount                          Location  \
# ...

# %%
startup_2019 = pd.read_csv(r'C:\Users\User\Desktop\AZUBI AFRICA\Projects\LP 1\startup_funding2019.csv')

startup_2020 = pd.read_csv(r'C:\Users\User\Desktop\AZUBI AFRICA\Projects\LP 1\startup_funding2020.csv')

startup_2021 = pd.read_csv(r'C:\Users\User\Desktop\AZUBI AFRICA\Projects\LP 1\startup_funding2021.csv')

startup_2019
# Out:
#       Company/Brand  Founded HeadQuarter                   Sector  \
# 0    Bombay Shaving      NaN         NaN                Ecommerce
# 1         Ruangguru   2014.0      Mumbai                   Edtech
# 2          Eduisfun      NaN      Mumbai                   Edtech
# 3          HomeLane   2014.0     Chennai          Interior design
# 4          Nu Genes   2004.0   Telangana                 AgriTech
# ..              ...      ...         ...                      ...
# 84     Infra.Market      NaN      Mumbai                Infratech
# 85              Oyo   2013.0    Gurugram              Hospitality
# 86       GoMechanic   2016.0       Delhi  Automobile & Technology
# 87           Spinny   2015.0       Delhi               Automobile
# 88  Ess Kay Fincorp      NaN   Rajasthan                  Banking
#
#                                          What it does  \
# 0          Provides a range of male grooming products
# 1   A learning platform that provides topic-based ...
# ...

# %%
startup_2020
# Out:
#      Company/Brand Founded HeadQuarter              Sector  \
# 0       Aqgromalin    2019     Chennai            AgriTech
# 1         Krayonnz    2019   Bangalore              EdTech
# 2     PadCare Labs    2018        Pune  Hygiene management
# 3            NCOME    2020   New Delhi              Escrow
# 4       Gramophone    2016      Indore            AgriTech
# ...            ...     ...         ...                 ...
# 1050  Leverage Edu     NaN       Delhi              Edtech
# 1051         EpiFi     NaN         NaN             Fintech
# 1052       Purplle    2012      Mumbai           Cosmetics
# 1053        Shuttl    2015       Delhi           Transport
# 1054         Pando    2017     Chennai            Logitech
#
#                                            What it does  \
# 0                          Cultivating Ideas for Profit
# 1     An academy-guardian-scholar centric ecosystem ...
# 2      Converting bio-hazardous waste to harmless waste
# ...

# %%
startup_2021
# Out:
#        Company/Brand  Founded HeadQuarter                 Sector  \
# 0     Unbox Robotics   2019.0   Bangalore             AI startup
# 1             upGrad   2015.0      Mumbai                 EdTech
# 2        Lead School   2012.0      Mumbai                 EdTech
# 3            Bizongo   2015.0      Mumbai         B2B E-commerce
# 4           FypMoney   2021.0    Gurugram                FinTech
# ...              ...      ...         ...                    ...
# 1204        Gigforce   2019.0    Gurugram  Staffing & Recruiting
# 1205          Vahdam   2015.0   New Delhi       Food & Beverages
# 1206    Leap Finance   2019.0   Bangalore     Financial Services
# 1207    CollegeDekho   2015.0    Gurugram                 EdTech
# 1208          WeRize   2019.0   Bangalore     Financial Services
#
#                                            What it does  \
# 0     Unbox Robotics builds on-demand AI-driven ware...
# 1        UpGrad is an online higher education platform.
# ...

# %% [markdown]
# ### STATING THE HYPOTHESIS
#
# ### HO (Null): Sector of service is not dependent on the amount raised.
#
# ### H1(Alternative): Sector of service is dependent on the amount raised.

# %% [markdown]
# ### STATING THE HYPOTHESIS
#
# ### HO (Null): Sector of service is not dependent on the amount raised.
#
# ### H1(Alternative): Sector of service is dependent on the amount raised.

# %% [markdown]
# ### ANALYTICAL QUESTIONS

# %% [markdown]
# ### 1) What is the total amount raised by all the investors
#
# ### 2) Which sector has the highest amount invested.
#
# ### 3) Which year has the most start up founded.
#
# ### 4) Which Headquarters has the highest  funding.
#
# ### 5) Which Company has the highest amount invested on and who is the investor.
#
# ### 6) What is the Maximum, Minimum and Average amount raised.

# %% [markdown]
# ### DATA PRE-PROCESSING

# %%
# 2018 STARTUP DATA PROCESSING

startup_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526 entries, 0 to 525
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company Name   526 non-null    object
#  1   Industry       526 non-null    object
#  2   Round/Series   526 non-null    object
#  3   Amount         526 non-null    object
#  4   Location       526 non-null    object
#  5   About Company  526 non-null    object
# dtypes: object(6)
# memory usage: 24.8+ KB

# %%
startup_2018.describe()
# Out:
#            Company Name Industry Round/Series Amount  \
# count               526      526          526    526
# unique              525      405           21    198
# top     TheCollegeFever        —         Seed      —
# freq                  2       30          280    148
#
#                            Location  \
# count                           526
# unique                           50
# top     Bangalore, Karnataka, India
# freq                            102
#
#                                             About Company
# count                                                 526
# unique                                                524
# top     TheCollegeFever is a hub for fun, fiesta and f...
# freq                                                    2

# %%
startup_2018.shape
# Out:
# (526, 6)

# %%
startup_2018.dtypes
# Out:
# Company Name     object
# Industry         object
# Round/Series     object
# Amount           object
# Location         object
# About Company    object
# dtype: object

# %%
startup_2018.isna().sum()
# Out:
# Company Name     0
# Industry         0
# Round/Series     0
# Amount           0
# Location         0
# About Company    0
# dtype: int64

# %%
startup_2018
# Out:
#           Company Name                                           Industry  \
# 0      TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1      Happy Cow Dairy                               Agriculture, Farming
# 2           MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3          PayMe India                        Financial Services, FinTech
# 4             Eunimart                 E-Commerce Platforms, Retail, SaaS
# ..                 ...                                                ...
# 521              Udaan   B2B, Business Development, Internet, Marketplace
# 522  Happyeasygo Group                                    Tourism, Travel
# 523             Mombay         Food and Beverage, Food Delivery, Internet
# 524         Droni Tech                             Information Technology
# 525            Netmeds         Biotechnology, Health Care, Pharmaceutical
#
#     Round/Series       Amount                          Location  \
# ...

# %% [markdown]
# ### spliting the industry

# %%
startup_2018['Industry'] = startup_2018['Industry'].apply(str)

startup_2018['Industry'] = startup_2018['Industry'].str.split(',').str[0]

startup_2018['Industry'] = startup_2018['Industry'].replace(',','',regex = True)

startup_2018
# Out:
#           Company Name                Industry Round/Series       Amount  \
# 0      TheCollegeFever         Brand Marketing         Seed       250000
# 1      Happy Cow Dairy             Agriculture         Seed  ₹40,000,000
# 2           MyLoanCare                  Credit     Series A  ₹65,000,000
# 3          PayMe India      Financial Services        Angel      2000000
# 4             Eunimart    E-Commerce Platforms         Seed            —
# ..                 ...                     ...          ...          ...
# 521              Udaan                     B2B     Series C    225000000
# 522  Happyeasygo Group                 Tourism     Series A            —
# 523             Mombay       Food and Beverage         Seed         7500
# 524         Droni Tech  Information Technology         Seed  ₹35,000,000
# 525            Netmeds           Biotechnology     Series C     35000000
#
#                              Location  \
# 0         Bangalore, Karnataka, India
# ...

# %% [markdown]
# ### SPLITING THE LOCATION

# %%
startup_2018['Location'] = startup_2018['Location'].apply(str)

startup_2018['Location'] = startup_2018['Location'].str.split(',').str[0]

startup_2018['Location'] = startup_2018['Location'].replace(',','',regex = True)

startup_2018
# Out:
#           Company Name                Industry Round/Series       Amount  \
# 0      TheCollegeFever         Brand Marketing         Seed       250000
# 1      Happy Cow Dairy             Agriculture         Seed  ₹40,000,000
# 2           MyLoanCare                  Credit     Series A  ₹65,000,000
# 3          PayMe India      Financial Services        Angel      2000000
# 4             Eunimart    E-Commerce Platforms         Seed            —
# ..                 ...                     ...          ...          ...
# 521              Udaan                     B2B     Series C    225000000
# 522  Happyeasygo Group                 Tourism     Series A            —
# 523             Mombay       Food and Beverage         Seed         7500
# 524         Droni Tech  Information Technology         Seed  ₹35,000,000
# 525            Netmeds           Biotechnology     Series C     35000000
#
#       Location                                      About Company
# ...

# %% [markdown]
# ### RENAMING THE COLUMNS

# %%
#startup_2018.rename(columns={'Company Name':'Company/Brand', 'Industry':'Sector', 'Round/Series':'Stage', 'Amount':'Amount ($)',
                            # 'Location':'HeadQuarter', 'About Company':'What it does'}, inplace = True)

# %% [markdown]
# ## CLEANING THE AMOUNT COLUMN

# %%
# REPLACING THE COMMAS WITH '', HYPHENS WITH "0", DOLLA SIGN WITH '' AND CONVERTING THEM TO STRING

startup_2018['Amount'] = startup_2018['Amount'].apply(str)

startup_2018['Amount'] = startup_2018['Amount'].replace(',','',regex = True)

startup_2018['Amount'] = startup_2018['Amount'].replace('—',0)


startup_2018
# Out:
#           Company Name                Industry Round/Series     Amount  \
# 0      TheCollegeFever         Brand Marketing         Seed     250000
# 1      Happy Cow Dairy             Agriculture         Seed  ₹40000000
# 2           MyLoanCare                  Credit     Series A  ₹65000000
# 3          PayMe India      Financial Services        Angel    2000000
# 4             Eunimart    E-Commerce Platforms         Seed          0
# ..                 ...                     ...          ...        ...
# 521              Udaan                     B2B     Series C  225000000
# 522  Happyeasygo Group                 Tourism     Series A          0
# 523             Mombay       Food and Beverage         Seed       7500
# 524         Droni Tech  Information Technology         Seed  ₹35000000
# 525            Netmeds           Biotechnology     Series C   35000000
#
#       Location                                      About Company
# ...

# %% [markdown]
# ### FEATURE ENGINEERING
#
# # Note: Exchange Rate: 0.0146 USD = 1 Rupee from 2018 USA Historical Data

# %%
# Addition of Amount_INR,Amount_USD to isolate the Rupees and the dollars

# Note: Exchange Rate: 0.0146 USD = 1 Rupee from 2018 USA Historical Data

startup_2018['Amount_INR'] = startup_2018['Amount'].str.rsplit('₹', n=2).str[1]

startup_2018['Amount_INR'] = startup_2018['Amount_INR'].apply(float).fillna(0)

startup_2018['Amount_USD'] = startup_2018['Amount_INR']* 0.0146

startup_2018['Amount_USD'] = startup_2018['Amount_USD'].replace(0,np.nan)

startup_2018['Amount_USD'] = startup_2018['Amount_USD'].fillna(startup_2018['Amount'])

startup_2018
# Out:
#           Company Name                Industry Round/Series     Amount  \
# 0      TheCollegeFever         Brand Marketing         Seed     250000
# 1      Happy Cow Dairy             Agriculture         Seed  ₹40000000
# 2           MyLoanCare                  Credit     Series A  ₹65000000
# 3          PayMe India      Financial Services        Angel    2000000
# 4             Eunimart    E-Commerce Platforms         Seed          0
# ..                 ...                     ...          ...        ...
# 521              Udaan                     B2B     Series C  225000000
# 522  Happyeasygo Group                 Tourism     Series A          0
# 523             Mombay       Food and Beverage         Seed       7500
# 524         Droni Tech  Information Technology         Seed  ₹35000000
# 525            Netmeds           Biotechnology     Series C   35000000
#
#       Location                                      About Company  Amount_INR  \
# ...

# %% [markdown]
# ###               CREATING THE YEAR OF FUNDING COLUMN

# %%
startup_2018['Year of Funding'] = '2018'

# %%
startup_2018
# Out:
#           Company Name                Industry Round/Series     Amount  \
# 0      TheCollegeFever         Brand Marketing         Seed     250000
# 1      Happy Cow Dairy             Agriculture         Seed  ₹40000000
# 2           MyLoanCare                  Credit     Series A  ₹65000000
# 3          PayMe India      Financial Services        Angel    2000000
# 4             Eunimart    E-Commerce Platforms         Seed          0
# ..                 ...                     ...          ...        ...
# 521              Udaan                     B2B     Series C  225000000
# 522  Happyeasygo Group                 Tourism     Series A          0
# 523             Mombay       Food and Beverage         Seed       7500
# 524         Droni Tech  Information Technology         Seed  ₹35000000
# 525            Netmeds           Biotechnology     Series C   35000000
#
#       Location                                      About Company  Amount_INR  \
# ...

# %%
# Converting the Amount_USD to string and Removing any commas or hypens.

# Change datatype to float

startup_2018['Amount_USD'] = startup_2018['Amount_USD'].apply(str)

startup_2018['Amount_USD'] = startup_2018['Amount_USD'].replace('$','',regex=True)

startup_2018['Amount_USD'] = startup_2018['Amount_USD'].apply(lambda x: float(str(x).replace('$','')))

startup_2018['Amount_USD'] = startup_2018['Amount_USD'].replace(0,np.nan)

startup_2018
# Out:
#           Company Name                Industry Round/Series     Amount  \
# 0      TheCollegeFever         Brand Marketing         Seed     250000
# 1      Happy Cow Dairy             Agriculture         Seed  ₹40000000
# 2           MyLoanCare                  Credit     Series A  ₹65000000
# 3          PayMe India      Financial Services        Angel    2000000
# 4             Eunimart    E-Commerce Platforms         Seed          0
# ..                 ...                     ...          ...        ...
# 521              Udaan                     B2B     Series C  225000000
# 522  Happyeasygo Group                 Tourism     Series A          0
# 523             Mombay       Food and Beverage         Seed       7500
# 524         Droni Tech  Information Technology         Seed  ₹35000000
# 525            Netmeds           Biotechnology     Series C   35000000
#
#       Location                                      About Company  Amount_INR  \
# ...

# %%
startup_2018.drop(columns=['Amount_INR','Amount'], inplace=True)

# %%
startup_2018
# Out:
#           Company Name                Industry Round/Series   Location  \
# 0      TheCollegeFever         Brand Marketing         Seed  Bangalore
# 1      Happy Cow Dairy             Agriculture         Seed     Mumbai
# 2           MyLoanCare                  Credit     Series A    Gurgaon
# 3          PayMe India      Financial Services        Angel      Noida
# 4             Eunimart    E-Commerce Platforms         Seed  Hyderabad
# ..                 ...                     ...          ...        ...
# 521              Udaan                     B2B     Series C  Bangalore
# 522  Happyeasygo Group                 Tourism     Series A    Haryana
# 523             Mombay       Food and Beverage         Seed     Mumbai
# 524         Droni Tech  Information Technology         Seed     Mumbai
# 525            Netmeds           Biotechnology     Series C    Chennai
#
#                                          About Company   Amount_USD  \
# ...

# %% [markdown]
# ## Renaming the Columns

# %%
startup_2018.rename(columns = {'Company Name':'Company/Brand','Industry':'Sector','Round/Series':'Stage',
                               'Amount_USD':'Amount($)','Location':'HeadQuarter','About Company':'What it does'}, inplace=True)

# %%
startup_2018
# Out:
#          Company/Brand                  Sector     Stage HeadQuarter  \
# 0      TheCollegeFever         Brand Marketing      Seed   Bangalore
# 1      Happy Cow Dairy             Agriculture      Seed      Mumbai
# 2           MyLoanCare                  Credit  Series A     Gurgaon
# 3          PayMe India      Financial Services     Angel       Noida
# 4             Eunimart    E-Commerce Platforms      Seed   Hyderabad
# ..                 ...                     ...       ...         ...
# 521              Udaan                     B2B  Series C   Bangalore
# 522  Happyeasygo Group                 Tourism  Series A     Haryana
# 523             Mombay       Food and Beverage      Seed      Mumbai
# 524         Droni Tech  Information Technology      Seed      Mumbai
# 525            Netmeds           Biotechnology  Series C     Chennai
#
#                                           What it does    Amount($)  \
# 0    TheCollegeFever is a hub for fun, fiesta and f...     250000.0
# ...

# %%
#Change year of Funding column datatype to int

startup_2018['Year of Funding'].astype(int)
# Out:
# 0      2018
# 1      2018
# 2      2018
# 3      2018
# 4      2018
#        ...
# 521    2018
# 522    2018
# 523    2018
# 524    2018
# 525    2018
# Name: Year of Funding, Length: 526, dtype: int32

# %%
# Confirming the datatype

startup_2018.dtypes
# Out:
# Company/Brand       object
# Sector              object
# Stage               object
# HeadQuarter         object
# What it does        object
# Amount($)          float64
# Year of Funding     object
# dtype: object

# %% [markdown]
# ### SAVING CLEANED 2018 DATASET

# %%
startup_2018.to_csv('cleaned_2018.csv', index = False)

# %% [markdown]
# ### PROCESSING 2020 DATASET

# %%
startup_2020
# Out:
#      Company/Brand Founded HeadQuarter              Sector  \
# 0       Aqgromalin    2019     Chennai            AgriTech
# 1         Krayonnz    2019   Bangalore              EdTech
# 2     PadCare Labs    2018        Pune  Hygiene management
# 3            NCOME    2020   New Delhi              Escrow
# 4       Gramophone    2016      Indore            AgriTech
# ...            ...     ...         ...                 ...
# 1050  Leverage Edu     NaN       Delhi              Edtech
# 1051         EpiFi     NaN         NaN             Fintech
# 1052       Purplle    2012      Mumbai           Cosmetics
# 1053        Shuttl    2015       Delhi           Transport
# 1054         Pando    2017     Chennai            Logitech
#
#                                            What it does  \
# 0                          Cultivating Ideas for Profit
# 1     An academy-guardian-scholar centric ecosystem ...
# 2      Converting bio-hazardous waste to harmless waste
# ...

# %%
startup_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1055 entries, 0 to 1054
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  1055 non-null   object
#  1   Founded        843 non-null    object
#  2   HeadQuarter    961 non-null    object
#  3   Sector         1042 non-null   object
#  4   What it does   1055 non-null   object
#  5   Founders       1043 non-null   object
#  6   Investor       1017 non-null   object
#  7   Amount($)      1052 non-null   object
#  8   Stage          591 non-null    object
#  9   Unnamed: 9     2 non-null      object
# dtypes: object(10)
# memory usage: 82.5+ KB

# %%
startup_2020.head()
# Out:
#   Company/Brand Founded HeadQuarter              Sector  \
# 0    Aqgromalin    2019     Chennai            AgriTech
# 1      Krayonnz    2019   Bangalore              EdTech
# 2  PadCare Labs    2018        Pune  Hygiene management
# 3         NCOME    2020   New Delhi              Escrow
# 4    Gramophone    2016      Indore            AgriTech
#
#                                         What it does  \
# 0                       Cultivating Ideas for Profit
# 1  An academy-guardian-scholar centric ecosystem ...
# 2   Converting bio-hazardous waste to harmless waste
# 3                       Escrow-as-a-service platform
# 4  Gramophone is an AgTech platform enabling acce...
#
#                                             Founders  \
# 0                    Prasanna Manogaran, Bharani C L
# 1                   Saurabh Dixit, Gurudutt Upadhyay
# 2                                    Ajinkya Dhariya
# 3                                      Ritesh Tiwari
# ...

# %%
startup_2020.isna().sum()
# Out:
# Company/Brand       0
# Founded           212
# HeadQuarter        94
# Sector             13
# What it does        0
# Founders           12
# Investor           38
# Amount($)           3
# Stage             464
# Unnamed: 9       1053
# dtype: int64

# %%
startup_2020.shape
# Out:
# (1055, 10)

# %% [markdown]
# ### WE ARE GOING TO CLEAN THIS DATA COLUMN BY COLUMN
#
# ### CLEANING COMPANY/BRAND COLUMN

# %%
startup_2020['Company/Brand'].isna().sum()
# Out:
# 0

# %%
startup_2020['Company/Brand']
# Out:
# 0         Aqgromalin
# 1           Krayonnz
# 2       PadCare Labs
# 3              NCOME
# 4         Gramophone
#             ...
# 1050    Leverage Edu
# 1051           EpiFi
# 1052         Purplle
# 1053          Shuttl
# 1054           Pando
# Name: Company/Brand, Length: 1055, dtype: object

# %% [markdown]
# ### THERE IS NO MISSING VALUES IN THE COMPANY/BRAND COLUMN

# %% [markdown]
# ### CLEANING THE 'FOUNDED ' COLUMN

# %%
startup_2020["Founded"].isnull().sum()
# Out:
# 212

# %% [markdown]
# ### There are 212 empty values.
#
# ### We will be using  mode or mean of the column to fill the missing values.

# %%
# copying the column

founded_2020 = startup_2020.Founded 

founded_2020
# Out:
# 0       2019
# 1       2019
# 2       2018
# 3       2020
# 4       2016
#         ...
# 1050     NaN
# 1051     NaN
# 1052    2012
# 1053    2015
# 1054    2017
# Name: Founded, Length: 1055, dtype: object

# %% [markdown]
# ### From above the it has "-" and "nan" values. They have to be dropped inorder to find mean and mode.

# %%
# searching for the index of the value "-" from the column
for i in range(startup_2020.shape[0]):
    if founded_2020[i] == "-":
        print(i)
# Out:
# 482

# %% [markdown]
# ### It has a Total number of 482 "-"and "nan" values that need to be dropped

# %%
founded_2020 = founded_2020.drop(482)

# %%
founded_2020 = founded_2020.dropna()

founded_2020
# Out:
# 0       2019
# 1       2019
# 2       2018
# 3       2020
# 4       2016
#         ...
# 1048    2016
# 1049    2017
# 1052    2012
# 1053    2015
# 1054    2017
# Name: Founded, Length: 842, dtype: object

# %%
founded_2020.unique()
# Out:
# array(['2019', '2018', '2020', '2016', '2008', '2015', '2017', '2014',
#        '1998', '2007', '2011', '1982', '2013', '2009', '2012', '1995',
#        '2010', '2006', '1978', '1999', '1994', '2005', '1973', '2002',
#        '2004', '2001'], dtype=object)

# %% [markdown]
# ### Founded_2020 is free from error for our calculation.
#
# ### Let us convert it to integer

# %%
# converting to int data type

founded_2020 = founded_2020.astype(int) 

founded_2020
# Out:
# 0       2019
# 1       2019
# 2       2018
# 3       2020
# 4       2016
#         ...
# 1048    2016
# 1049    2017
# 1052    2012
# 1053    2015
# 1054    2017
# Name: Founded, Length: 842, dtype: int32

# %%
founded_2020.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 842 entries, 0 to 1054
# Series name: Founded
# Non-Null Count  Dtype
# --------------  -----
# 842 non-null    int32
# dtypes: int32(1)
# memory usage: 9.9 KB

# %% [markdown]
# ### Calculating Mode and Mean

# %%
founded_2020.mode()
# Out:
# 0    2015
# Name: Founded, dtype: int32

# %%
founded_2020.mean()
# Out:
# 2015.3634204275534

# %% [markdown]
# ### The Average is 2015.
#
# ###  2015  will be used as an imputer for missed value for column Founded.

# %%
startup_2020.Founded.unique()
# Out:
# array(['2019', '2018', '2020', '2016', '2008', '2015', '2017', '2014',
#        '1998', '2007', '2011', '1982', '2013', '2009', '2012', '1995',
#        '2010', '2006', '1978', nan, '1999', '1994', '2005', '1973', '-',
#        '2002', '2004', '2001'], dtype=object)

# %%
# repalcing "-" with 2015

startup_2020.Founded = startup_2020.Founded.replace("-",2015) 


# replacing NaN 

startup_2020.Founded = startup_2020.Founded.fillna(2015)

# %%
startup_2020.Founded.isnull().any()
# Out:
# False

# %% [markdown]
# ### NOW, OUR "FOUNDED " COLUMN IS CLEANED

# %% [markdown]
# ### CLEANING THE SECTOR COLUMN

# %%
# checking if there is MISING value

startup_2020.Sector.isnull().sum()
# Out:
# 13

# %% [markdown]
# ###  WE HAVE 13 MISSING VALUES INTHE SECTOR COLUMN

# %%
# copying the column

sector_2020 = startup_2020.Sector.isnull()

# %%
# finding frequented value

mode = startup_2020.Sector.mode() 

mode
# Out:
# 0    Fintech
# Name: Sector, dtype: object

# %%
 # searching for empty/nan value

for i in range(len(sector_2020)):
    if sector_2020[i] == True:
        startup_2020.Sector[i] = mode

# %%
startup_2020.Sector.isnull().any()
# Out:
# False

# %% [markdown]
# ### SECTOR COLUMN IS NOW CLEANED

# %% [markdown]
# ### CLEANING INVESTOR COLUMN

# %%
# CHECKING FOR MISSING VALUES IN INVESTOR COLUMN

startup_2020.Investor.isnull().sum()
# Out:
# 38

# %% [markdown]
# ### It has a total of 38 missing values

# %%
#FILLING THE MISSING VALUES WITH " UNDEFINED"


investor_2020 = startup_2020.Investor.isnull()

# %%
for i in range(len(investor_2020)):
    if investor_2020[i] == True:
        startup_2020.Investor[i] = "undefined"

# %%
startup_2020.Investor.isnull().sum()
# Out:
# 0

# %% [markdown]
# ### THE INVESTOR COLUMN IS CLEANED NOW

# %% [markdown]
# ### CLEANING THE AMOUNT COLUMN

# %%
startup_2020["Amount($)"].unique()
# Out:
# array(['$200,000', '$100,000', 'Undisclosed', '$400,000', '$340,000',
#        '$600,000', '$45,000,000', '$1,000,000', '$2,000,000',
#        '$1,200,000', '$660,000,000', '$120,000', '$7,500,000',
#        '$5,000,000', '$500,000', '$3,000,000', '$10,000,000',
#        '$145,000,000', '$100,000,000', nan, '$21,000,000', '$4,000,000',
#        '$20,000,000', '$560,000', '$275,000', '$4,500,000', '$15,000,000',
#        '$390,000,000', '$7,000,000', '$5,100,000', '$700,000,000',
#        '$2,300,000', '$700,000', '$19,000,000', '$9,000,000',
#        '$40,000,000', '$750,000', '$1,500,000', '$7,800,000',
#        '$50,000,000', '$80,000,000', '$30,000,000', '$1,700,000',
#        '$2,500,000', '$40,000', '$33,000,000', '$35,000,000', '$300,000',
#        '$25,000,000', '$3,500,000', '$200,000,000', '$6,000,000',
#        '$1,300,000', '$4,100,000', '$575,000', '$800,000', '$28,000,000',
#        '$18,000,000', '$3,200,000', '$900,000', '$250,000', '$4,700,000',
# ...

# %% [markdown]
# ### FROM THE ABOVE, THE COLUMN HAS "NAN" AND "UNDISCLOSED" VALUES WHICH NEED TO TREATED

# %% [markdown]
# ### WE ARE GOING TO TREAT THEM BY REPLACING THEM WITH THEIR MEAN VALUES

# %%
# copying the column

amount_2020 = startup_2020["Amount($)"]

# %%
# replacing values

amount_2020 = amount_2020.apply(lambda x: str(x).replace(",",""))
amount_2020 = amount_2020.apply(lambda x: str(x).replace("Undisclosed","0"))
amount_2020 = amount_2020.apply(lambda x: str(x).replace("$",""))
amount_2020 = amount_2020.apply(lambda x: str(x).replace("Undislosed","0"))
amount_2020 = amount_2020.apply(lambda x: str(x).replace("Undiclsosed","0"))
amount_2020 = amount_2020.apply(lambda x: str(x).replace("nan","0"))

# %%
amount_2020.unique()
# Out:
# array(['200000', '100000', '0', '400000', '340000', '600000', '45000000',
#        '1000000', '2000000', '1200000', '660000000', '120000', '7500000',
#        '5000000', '500000', '3000000', '10000000', '145000000',
#        '100000000', '21000000', '4000000', '20000000', '560000', '275000',
#        '4500000', '15000000', '390000000', '7000000', '5100000',
#        '700000000', '2300000', '700000', '19000000', '9000000',
#        '40000000', '750000', '1500000', '7800000', '50000000', '80000000',
#        '30000000', '1700000', '2500000', '40000', '33000000', '35000000',
#        '300000', '25000000', '3500000', '200000000', '6000000', '1300000',
#        '4100000', '575000', '800000', '28000000', '18000000', '3200000',
#        '900000', '250000', '4700000', '75000000', '8000000', '121000000',
#        '55000000', '3300000', '11000000', '16000000', '5400000',
#        '150000000', '4200000', '22000000', '52000000', '1100000',
# ...

# %%
# eliminating space

data = amount_2020.str.endswith(" ")

for i in range(len(amount_2020)):
    if data[i]:
        amount_2020[i] = amount_2020[i][:-1]

# %%
# there are two columns having two values

val = {}
for i in range(len(amount_2020)):
    if " " in amount_2020[i]:
        val[i] = amount_2020[i]
val
# Out:
# {465: '887000 23000000', 472: '800000000 to 850000000', 548: ' 8700000'}

# %%
# a. replacing values with their mean

val2 = val[465].split(" ")
val2

a = float(val2[0])
b = float(val2[1])

mean = (a + b) / 2
amount_2020[465] = mean

# %%
# b. replacing values with their mean

val3 = val[472].split(" to ")
val3

c = float(val2[0])
d = float(val2[1])

mean2 = (c + d) / 2
amount_2020[472] = mean2

# %%
# converting to float

amount_2020 = amount_2020.astype(float)

# %%
amount_2020
# Out:
# 0         200000.0
# 1         100000.0
# 2              0.0
# 3         400000.0
# 4         340000.0
#            ...
# 1050     1500000.0
# 1051    13200000.0
# 1052     8000000.0
# 1053     8043000.0
# 1054     9000000.0
# Name: Amount($), Length: 1055, dtype: float64

# %%
#FINDING THE MAEN, MODE AND MEDIA

mean_val = amount_2020.mean()

mean_val
# Out:
# 85860249.91073933

# %%
amount_2020.mode()
# Out:
# 0    0.0
# Name: Amount($), dtype: float64

# %%
amount_2020.median()
# Out:
# 1403400.0

# %%
# replacing 0.0 by mean value

amount_2020 = amount_2020.replace(0.0 ,mean_val) 

amount_2020
# Out:
# 0       2.000000e+05
# 1       1.000000e+05
# 2       8.586025e+07
# 3       4.000000e+05
# 4       3.400000e+05
#             ...
# 1050    1.500000e+06
# 1051    1.320000e+07
# 1052    8.000000e+06
# 1053    8.043000e+06
# 1054    9.000000e+06
# Name: Amount($), Length: 1055, dtype: float64

# %%
 # substituting the columns

startup_2020["Amount($)"] = amount_2020

# %%
startup_2020
# Out:
#      Company/Brand Founded HeadQuarter              Sector  \
# 0       Aqgromalin    2019     Chennai            AgriTech
# 1         Krayonnz    2019   Bangalore              EdTech
# 2     PadCare Labs    2018        Pune  Hygiene management
# 3            NCOME    2020   New Delhi              Escrow
# 4       Gramophone    2016      Indore            AgriTech
# ...            ...     ...         ...                 ...
# 1050  Leverage Edu    2015       Delhi              Edtech
# 1051         EpiFi    2015         NaN             Fintech
# 1052       Purplle    2012      Mumbai           Cosmetics
# 1053        Shuttl    2015       Delhi           Transport
# 1054         Pando    2017     Chennai            Logitech
#
#                                            What it does  \
# 0                          Cultivating Ideas for Profit
# 1     An academy-guardian-scholar centric ecosystem ...
# 2      Converting bio-hazardous waste to harmless waste
# ...

# %% [markdown]
# ### THE AMOUNT COLUMN IS CLEAN NOW

# %% [markdown]
# ### LET NOW CLEAN THE FOUNDERS COLUMN

# %%
startup_2020.Founders.isnull().sum()
# Out:
# 12

# %% [markdown]
# ### It has 12 null values

# %%
# Let replace the null values with "Undefined"

founders_2020 = startup_2020.Founders.isnull()

founders_2020
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1050    False
# 1051    False
# 1052    False
# 1053    False
# 1054    False
# Name: Founders, Length: 1055, dtype: bool

# %%
for i in range(len(founders_2020)):
    if founders_2020[i] == True:
        startup_2020.Founders[i] = "Undefined"
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_6480\2141025315.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   startup_2020.Founders[i] = "Undefined"

# %%
startup_2020.Founders.isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Now, we are go to go as the Founders column is clean now..

# %% [markdown]
# ### LET CLEAN THE STAGE COLUMN

# %%
startup_2020.Stage.unique()
# Out:
# array([nan, 'Pre-seed', 'Seed', 'Pre-series A', 'Pre-series', 'Series C',
#        'Series A', 'Series B', 'Debt', 'Pre-series C', 'Pre-series B',
#        'Series E', 'Bridge', 'Series D', 'Series B2', 'Series F',
#        'Pre- series A', 'Edge', 'Series H', 'Pre-Series B', 'Seed A',
#        'Series A-1', 'Seed Funding', 'Pre-Seed', 'Seed round',
#        'Pre-seed Round', 'Seed Round & Series A', 'Pre Series A',
#        'Pre seed Round', 'Angel Round', 'Pre series A1', 'Series E2',
#        'Pre series A', 'Seed Round', 'Bridge Round', 'Pre seed round',
#        'Pre series B', 'Pre series C', 'Seed Investment', 'Series D1',
#        'Mid series', 'Series C, D', 'Seed funding'], dtype=object)

# %%
# Filling 

startup_2020.Stage = startup_2020.Stage.fillna(startup_2020.Stage.mode()[0])

# %%
startup_2020
# Out:
#      Company/Brand Founded HeadQuarter              Sector  \
# 0       Aqgromalin    2019     Chennai            AgriTech
# 1         Krayonnz    2019   Bangalore              EdTech
# 2     PadCare Labs    2018        Pune  Hygiene management
# 3            NCOME    2020   New Delhi              Escrow
# 4       Gramophone    2016      Indore            AgriTech
# ...            ...     ...         ...                 ...
# 1050  Leverage Edu    2015       Delhi              Edtech
# 1051         EpiFi    2015         NaN             Fintech
# 1052       Purplle    2012      Mumbai           Cosmetics
# 1053        Shuttl    2015       Delhi           Transport
# 1054         Pando    2017     Chennai            Logitech
#
#                                            What it does  \
# 0                          Cultivating Ideas for Profit
# 1     An academy-guardian-scholar centric ecosystem ...
# 2      Converting bio-hazardous waste to harmless waste
# ...

# %%
startup_2020['Year of Funding'] = '2020'

# %%
startup_2020
# Out:
#      Company/Brand Founded HeadQuarter              Sector  \
# 0       Aqgromalin    2019     Chennai            AgriTech
# 1         Krayonnz    2019   Bangalore              EdTech
# 2     PadCare Labs    2018        Pune  Hygiene management
# 3            NCOME    2020   New Delhi              Escrow
# 4       Gramophone    2016      Indore            AgriTech
# ...            ...     ...         ...                 ...
# 1050  Leverage Edu    2015       Delhi              Edtech
# 1051         EpiFi    2015         NaN             Fintech
# 1052       Purplle    2012      Mumbai           Cosmetics
# 1053        Shuttl    2015       Delhi           Transport
# 1054         Pando    2017     Chennai            Logitech
#
#                                            What it does  \
# 0                          Cultivating Ideas for Profit
# 1     An academy-guardian-scholar centric ecosystem ...
# 2      Converting bio-hazardous waste to harmless waste
# ...

# %%
# DROPPING UNNAMED COLUMN

startup_2020 = startup_2020.drop(columns = "Unnamed: 9")

# %%
startup_2020
# Out:
#      Company/Brand Founded HeadQuarter              Sector  \
# 0       Aqgromalin    2019     Chennai            AgriTech
# 1         Krayonnz    2019   Bangalore              EdTech
# 2     PadCare Labs    2018        Pune  Hygiene management
# 3            NCOME    2020   New Delhi              Escrow
# 4       Gramophone    2016      Indore            AgriTech
# ...            ...     ...         ...                 ...
# 1050  Leverage Edu    2015       Delhi              Edtech
# 1051         EpiFi    2015         NaN             Fintech
# 1052       Purplle    2012      Mumbai           Cosmetics
# 1053        Shuttl    2015       Delhi           Transport
# 1054         Pando    2017     Chennai            Logitech
#
#                                            What it does  \
# 0                          Cultivating Ideas for Profit
# 1     An academy-guardian-scholar centric ecosystem ...
# 2      Converting bio-hazardous waste to harmless waste
# ...

# %%
file_name = "cleaned_2020.csv"

startup_2020.to_csv(file_name)

# %% [markdown]
# ### STARTUP_2021 PROCESSING

# %%
startup_2021
# Out:
#        Company/Brand  Founded HeadQuarter                 Sector  \
# 0     Unbox Robotics   2019.0   Bangalore             AI startup
# 1             upGrad   2015.0      Mumbai                 EdTech
# 2        Lead School   2012.0      Mumbai                 EdTech
# 3            Bizongo   2015.0      Mumbai         B2B E-commerce
# 4           FypMoney   2021.0    Gurugram                FinTech
# ...              ...      ...         ...                    ...
# 1204        Gigforce   2019.0    Gurugram  Staffing & Recruiting
# 1205          Vahdam   2015.0   New Delhi       Food & Beverages
# 1206    Leap Finance   2019.0   Bangalore     Financial Services
# 1207    CollegeDekho   2015.0    Gurugram                 EdTech
# 1208          WeRize   2019.0   Bangalore     Financial Services
#
#                                            What it does  \
# 0     Unbox Robotics builds on-demand AI-driven ware...
# 1        UpGrad is an online higher education platform.
# ...

# %%
startup_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1209 entries, 0 to 1208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  1209 non-null   object
#  1   Founded        1208 non-null   float64
#  2   HeadQuarter    1208 non-null   object
#  3   Sector         1209 non-null   object
#  4   What it does   1209 non-null   object
#  5   Founders       1205 non-null   object
#  6   Investor       1147 non-null   object
#  7   Amount($)      1206 non-null   object
#  8   Stage          781 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 85.1+ KB

# %%
startup_2021.head()
# Out:
#     Company/Brand  Founded HeadQuarter          Sector  \
# 0  Unbox Robotics   2019.0   Bangalore      AI startup
# 1          upGrad   2015.0      Mumbai          EdTech
# 2     Lead School   2012.0      Mumbai          EdTech
# 3         Bizongo   2015.0      Mumbai  B2B E-commerce
# 4        FypMoney   2021.0    Gurugram         FinTech
#
#                                         What it does  \
# 0  Unbox Robotics builds on-demand AI-driven ware...
# 1     UpGrad is an online higher education platform.
# 2  LEAD School offers technology based school tra...
# 3  Bizongo is a business-to-business online marke...
# 4  FypMoney is Digital NEO Bank for Teenagers, em...
#
#                                             Founders  \
# 0                        Pramod Ghadge, Shahid Memon
# 1  Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                         Smita Deorah, Sumeet Mehta
# 3            Aniket Deb, Ankit Tomar, Sachin Agrawal
# ...

# %%
# CHECKING FOR MISSING VALUES

startup_2021.isna().sum()
# Out:
# Company/Brand      0
# Founded            1
# HeadQuarter        1
# Sector             0
# What it does       0
# Founders           4
# Investor          62
# Amount($)          3
# Stage            428
# dtype: int64

# %%
startup_2021.duplicated().sum()
# Out:
# 19

# %% [markdown]
# ### LET'S START FROM THE FOUNDED COLUMN FOR THE CLEANING

# %%
 startup_2021.Founded.unique()
# Out:
# array([2019., 2015., 2012., 2021., 2014., 2018., 2016., 2020., 2010.,
#        2017., 1993., 2008., 2013., 1999., 1989., 2011.,   nan, 2009.,
#        2002., 1994., 2006., 2000., 2007., 1978., 2003., 1998., 1991.,
#        1984., 2004., 2005., 1963.])

# %%
startup_2021.Founded.isna().sum()
# Out:
# 1

# %% [markdown]
# ### the Founded Column has only 1 nan value. We can use the mean or the mode to fill it

# %%
# SETTING THE DATATYPE FOR THE FOUNDED COLUMN TO STRING

startup_2021['Founded'] = startup_2021['Founded'].replace(np.nan, 0)

startup_2021['Founded'] = startup_2021['Founded'].astype(int)

startup_2021['Founded']
# Out:
# 0       2019
# 1       2015
# 2       2012
# 3       2015
# 4       2021
#         ...
# 1204    2019
# 1205    2015
# 1206    2019
# 1207    2015
# 1208    2019
# Name: Founded, Length: 1209, dtype: int32

# %%
# calculating the mean and mode

startup_2021['Founded'].mean()
# Out:
# 2014.987593052109

# %%
# mode

startup_2021['Founded'].mode()
# Out:
# 0    2020
# Name: Founded, dtype: int32

# %%
# Using the Mean to replace "0"

startup_2021.Founded = startup_2021.Founded.replace("0",2015)

startup_2021.Founded
# Out:
# 0       2019
# 1       2015
# 2       2012
# 3       2015
# 4       2021
#         ...
# 1204    2019
# 1205    2015
# 1206    2019
# 1207    2015
# 1208    2019
# Name: Founded, Length: 1209, dtype: int32

# %%
startup_2021.Founded.isna().sum()
# Out:
# 0

# %% [markdown]
# ### Our Founded Column is clean now.

# %% [markdown]
# ### CLEANING OF THE HEADQUARTERS COLUMN

# %%
startup_2021['HeadQuarter'].unique()
# Out:
# array(['Bangalore', 'Mumbai', 'Gurugram', 'New Delhi', 'Hyderabad',
#        'Jaipur', 'Ahmadabad', 'Chennai', nan,
#        'Small Towns, Andhra Pradesh', 'Goa', 'Rajsamand', 'Ranchi',
#        'Faridabad, Haryana', 'Gujarat', 'Pune', 'Thane', 'Computer Games',
#        'Cochin', 'Noida', 'Chandigarh', 'Gurgaon', 'Vadodara',
#        'Food & Beverages', 'Pharmaceuticals\t#REF!', 'Gurugram\t#REF!',
#        'Kolkata', 'Ahmedabad', 'Mohali', 'Haryana', 'Indore', 'Powai',
#        'Ghaziabad', 'Nagpur', 'West Bengal', 'Patna', 'Samsitpur',
#        'Lucknow', 'Telangana', 'Silvassa', 'Thiruvananthapuram',
#        'Faridabad', 'Roorkee', 'Ambernath', 'Panchkula', 'Surat',
#        'Coimbatore', 'Andheri', 'Mangalore', 'Telugana', 'Bhubaneswar',
#        'Kottayam', 'Beijing', 'Panaji', 'Satara', 'Orissia', 'Jodhpur',
#        'New York', 'Santra', 'Mountain View, CA', 'Trivandrum',
#        'Jharkhand', 'Kanpur', 'Bhilwara', 'Guwahati',
# ...

# %%
startup_2021['HeadQuarter'].isna().sum()
# Out:
# 1

# %%
startup_2021['HeadQuarter'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1209 entries, 0 to 1208
# Series name: HeadQuarter
# Non-Null Count  Dtype
# --------------  -----
# 1208 non-null   object
# dtypes: object(1)
# memory usage: 9.6+ KB

# %%
# Replacing NAN values with "Undefined"

headquarters_2021 = startup_2021.HeadQuarter.isnull()

headquarters_2021
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1204    False
# 1205    False
# 1206    False
# 1207    False
# 1208    False
# Name: HeadQuarter, Length: 1209, dtype: bool

# %%
# Replacing the 'NAN' value with Keyword "Undefined"

for i in range(len(headquarters_2021)):
    if headquarters_2021[i] == True:
        startup_2021.HeadQuarter[i] = "Undefined"
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_6480\1738805364.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   startup_2021.HeadQuarter[i] = "Undefined"

# %%
startup_2021.HeadQuarter.isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Now, the Headquarters Column is great.
#
#
# ### LET'S LOOK AT THE FOUNDERS COLUMN TO CLEAN IT

# %%
startup_2021['Founders'].isna().sum()
# Out:
# 4

# %%
startup_2021['Founders'].unique()
# Out:
# array(['Pramod Ghadge, Shahid Memon',
#        'Mayank Kumar, Phalgun Kompalli, Ravijot Chugh, Ronnie Screwvala',
#        'Smita Deorah, Sumeet Mehta', ..., 'Bala Sarda',
#        'Arnav Kumar, Vaibhav Singh', 'Vishal Chopra, Himanshu Gupta'],
#       dtype=object)

# %%
founders_2021 = startup_2021.Founders.isnull()

founders_2021
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1204    False
# 1205    False
# 1206    False
# 1207    False
# 1208    False
# Name: Founders, Length: 1209, dtype: bool

# %%
# Replacing the '...' value with Keyword "Undefined"

for i in range(len(founders_2021)):
    if founders_2021[i] == True:
        startup_2021.Founders[i] = "Undefined"
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_6480\2680666504.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   startup_2021.Founders[i] = "Undefined"

# %%
startup_2021.Founders.isnull().sum()
# Out:
# 0

# %% [markdown]
# ### The Founder column is Cleaned now
#
#
# ### CLEANING OF THE INVESTOR COLUMN

# %%
startup_2021.Investor.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1209 entries, 0 to 1208
# Series name: Investor
# Non-Null Count  Dtype
# --------------  -----
# 1147 non-null   object
# dtypes: object(1)
# memory usage: 9.6+ KB

# %%
investors_2021 = startup_2021.Investor.isna().sum()

investors_2021
# Out:
# 62

# %%
startup_2021['Investor'] = startup_2021['Investor'].apply(str)


# Replacing the 'missing' values with Keyword "Unknown"
#for i in range(investors_2021):
    #if investors_2021[i] == True:
       # startup_2021.Investor[i] = "unknown"
        
#startup_2021.Investor.info()

# %%
startup_2021.isna().sum()
# Out:
# Company/Brand      0
# Founded            0
# HeadQuarter        0
# Sector             0
# What it does       0
# Founders           0
# Investor           0
# Amount($)          3
# Stage            428
# dtype: int64

# %% [markdown]
# ### The Investor column is now Clean.
#
#
# # CLEANING OF THE AMOUNT COLUMN

# %%
startup_2021['Amount($)'].isna().sum()
# Out:
# 3

# %%
startup_2021['Amount($)'].unique()
# Out:
# array(['$1,200,000', '$120,000,000', '$30,000,000', '$51,000,000',
#        '$2,000,000', '$188,000,000', '$200,000', 'Undisclosed',
#        '$1,000,000', '$3,000,000', '$100,000', '$700,000', '$9,000,000',
#        '$40,000,000', '$49,000,000', '$400,000', '$300,000',
#        '$25,000,000', '$160,000,000', '$150,000', '$1,800,000',
#        '$5,000,000', '$850,000', '$53,000,000', '$500,000', '$1,100,000',
#        '$6,000,000', '$800,000', '$10,000,000', '$21,000,000',
#        '$7,500,000', '$26,000,000', '$7,400,000', '$1,500,000',
#        '$600,000', '$800,000,000', '$17,000,000', '$3,500,000',
#        '$15,000,000', '$215,000,000', '$2,500,000', '$350,000,000',
#        '$5,500,000', '$83,000,000', '$110,000,000', '$500,000,000',
#        '$65,000,000', '$150,000,000,000', '$300,000,000', '$2,200,000',
#        '$35,000,000', '$140,000,000', '$4,000,000', '$13,000,000', nan,
#        '$Undisclosed', '$2000000', '$800000', '$6000000', '$2500000',
# ...

# %%
# converting the datatype to string

startup_2021['Amount($)'] = startup_2021['Amount($)'].apply(str)


# Removing the comas and spaces

startup_2021['Amount($)'].replace(',','', inplace = True, regex = True)

startup_2021
# Out:
#        Company/Brand  Founded HeadQuarter                 Sector  \
# 0     Unbox Robotics     2019   Bangalore             AI startup
# 1             upGrad     2015      Mumbai                 EdTech
# 2        Lead School     2012      Mumbai                 EdTech
# 3            Bizongo     2015      Mumbai         B2B E-commerce
# 4           FypMoney     2021    Gurugram                FinTech
# ...              ...      ...         ...                    ...
# 1204        Gigforce     2019    Gurugram  Staffing & Recruiting
# 1205          Vahdam     2015   New Delhi       Food & Beverages
# 1206    Leap Finance     2019   Bangalore     Financial Services
# 1207    CollegeDekho     2015    Gurugram                 EdTech
# 1208          WeRize     2019   Bangalore     Financial Services
#
#                                            What it does  \
# 0     Unbox Robotics builds on-demand AI-driven ware...
# 1        UpGrad is an online higher education platform.
# ...

# %%
startup_2021['Amount($)'].unique()
# Out:
# array(['$1200000', '$120000000', '$30000000', '$51000000', '$2000000',
#        '$188000000', '$200000', 'Undisclosed', '$1000000', '$3000000',
#        '$100000', '$700000', '$9000000', '$40000000', '$49000000',
#        '$400000', '$300000', '$25000000', '$160000000', '$150000',
#        '$1800000', '$5000000', '$850000', '$53000000', '$500000',
#        '$1100000', '$6000000', '$800000', '$10000000', '$21000000',
#        '$7500000', '$26000000', '$7400000', '$1500000', '$600000',
#        '$800000000', '$17000000', '$3500000', '$15000000', '$215000000',
#        '$2500000', '$350000000', '$5500000', '$83000000', '$110000000',
#        '$500000000', '$65000000', '$150000000000', '$300000000',
#        '$2200000', '$35000000', '$140000000', '$4000000', '$13000000',
#        'nan', '$Undisclosed', '$9500000', '$8000000', 'Upsparks',
#        '$12000000', '$1700000', '$150000000', '$100000000', '$225000000',
#        '$6700000', '$1300000', '$20000000', '$250000', '$52000000',
# ...

# %%
# Replacing the "nan" with "0"

#startup_2021['Amount($)'].replace('nan',np.nan, inplace = True, regex = True)


# converting to float datatype
#startup_2021['Amount($)']= pd.to_numeric(startup_2021['Amount($)'])
#startup_2021['Amount($)'] = startup_2021['Amount($)'].apply(float)

# %%
startup_2021['Amount($)'].isna().sum()
# Out:
# 0

# %%
startup_2021['Amount($)'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1209 entries, 0 to 1208
# Series name: Amount($)
# Non-Null Count  Dtype
# --------------  -----
# 1209 non-null   object
# dtypes: object(1)
# memory usage: 9.6+ KB

# %%
startup_2021
# Out:
#        Company/Brand  Founded HeadQuarter                 Sector  \
# 0     Unbox Robotics     2019   Bangalore             AI startup
# 1             upGrad     2015      Mumbai                 EdTech
# 2        Lead School     2012      Mumbai                 EdTech
# 3            Bizongo     2015      Mumbai         B2B E-commerce
# 4           FypMoney     2021    Gurugram                FinTech
# ...              ...      ...         ...                    ...
# 1204        Gigforce     2019    Gurugram  Staffing & Recruiting
# 1205          Vahdam     2015   New Delhi       Food & Beverages
# 1206    Leap Finance     2019   Bangalore     Financial Services
# 1207    CollegeDekho     2015    Gurugram                 EdTech
# 1208          WeRize     2019   Bangalore     Financial Services
#
#                                            What it does  \
# 0     Unbox Robotics builds on-demand AI-driven ware...
# 1        UpGrad is an online higher education platform.
# ...

# %%
startup_2021['Amount($)'].unique()
# Out:
# array(['$1200000', '$120000000', '$30000000', '$51000000', '$2000000',
#        '$188000000', '$200000', 'Undisclosed', '$1000000', '$3000000',
#        '$100000', '$700000', '$9000000', '$40000000', '$49000000',
#        '$400000', '$300000', '$25000000', '$160000000', '$150000',
#        '$1800000', '$5000000', '$850000', '$53000000', '$500000',
#        '$1100000', '$6000000', '$800000', '$10000000', '$21000000',
#        '$7500000', '$26000000', '$7400000', '$1500000', '$600000',
#        '$800000000', '$17000000', '$3500000', '$15000000', '$215000000',
#        '$2500000', '$350000000', '$5500000', '$83000000', '$110000000',
#        '$500000000', '$65000000', '$150000000000', '$300000000',
#        '$2200000', '$35000000', '$140000000', '$4000000', '$13000000',
#        'nan', '$Undisclosed', '$9500000', '$8000000', 'Upsparks',
#        '$12000000', '$1700000', '$150000000', '$100000000', '$225000000',
#        '$6700000', '$1300000', '$20000000', '$250000', '$52000000',
# ...

# %%
# Calculating the mean

#mean_value = startup_2021['Amount($)'].mean()

#mean_value

# %%
# Replacing "0" with the mean value

#startup_2021['Amount($)'].replace('0.0',mean_value, inplace = True, regex = True)

#startup_2021['Amount($)'].replace('nan',mean_value)

# %%
startup_2021['Amount($)'].unique()
# Out:
# array(['$1200000', '$120000000', '$30000000', '$51000000', '$2000000',
#        '$188000000', '$200000', 'Undisclosed', '$1000000', '$3000000',
#        '$100000', '$700000', '$9000000', '$40000000', '$49000000',
#        '$400000', '$300000', '$25000000', '$160000000', '$150000',
#        '$1800000', '$5000000', '$850000', '$53000000', '$500000',
#        '$1100000', '$6000000', '$800000', '$10000000', '$21000000',
#        '$7500000', '$26000000', '$7400000', '$1500000', '$600000',
#        '$800000000', '$17000000', '$3500000', '$15000000', '$215000000',
#        '$2500000', '$350000000', '$5500000', '$83000000', '$110000000',
#        '$500000000', '$65000000', '$150000000000', '$300000000',
#        '$2200000', '$35000000', '$140000000', '$4000000', '$13000000',
#        'nan', '$Undisclosed', '$9500000', '$8000000', 'Upsparks',
#        '$12000000', '$1700000', '$150000000', '$100000000', '$225000000',
#        '$6700000', '$1300000', '$20000000', '$250000', '$52000000',
# ...

# %%
# Removing the Dollar sign

startup_2021['Amount($)'] = startup_2021['Amount($)'].str.replace('$','')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_6480\2515805084.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   startup_2021['Amount($)'] = startup_2021['Amount($)'].str.replace('$','')

# %%
startup_2021
# Out:
#        Company/Brand  Founded HeadQuarter                 Sector  \
# 0     Unbox Robotics     2019   Bangalore             AI startup
# 1             upGrad     2015      Mumbai                 EdTech
# 2        Lead School     2012      Mumbai                 EdTech
# 3            Bizongo     2015      Mumbai         B2B E-commerce
# 4           FypMoney     2021    Gurugram                FinTech
# ...              ...      ...         ...                    ...
# 1204        Gigforce     2019    Gurugram  Staffing & Recruiting
# 1205          Vahdam     2015   New Delhi       Food & Beverages
# 1206    Leap Finance     2019   Bangalore     Financial Services
# 1207    CollegeDekho     2015    Gurugram                 EdTech
# 1208          WeRize     2019   Bangalore     Financial Services
#
#                                            What it does  \
# 0     Unbox Robotics builds on-demand AI-driven ware...
# 1        UpGrad is an online higher education platform.
# ...

# %%
# Creating the Year of Funding Column

startup_2021['Year of Funding'] = '2021'

# %%
startup_2021
# Out:
#        Company/Brand  Founded HeadQuarter                 Sector  \
# 0     Unbox Robotics     2019   Bangalore             AI startup
# 1             upGrad     2015      Mumbai                 EdTech
# 2        Lead School     2012      Mumbai                 EdTech
# 3            Bizongo     2015      Mumbai         B2B E-commerce
# 4           FypMoney     2021    Gurugram                FinTech
# ...              ...      ...         ...                    ...
# 1204        Gigforce     2019    Gurugram  Staffing & Recruiting
# 1205          Vahdam     2015   New Delhi       Food & Beverages
# 1206    Leap Finance     2019   Bangalore     Financial Services
# 1207    CollegeDekho     2015    Gurugram                 EdTech
# 1208          WeRize     2019   Bangalore     Financial Services
#
#                                            What it does  \
# 0     Unbox Robotics builds on-demand AI-driven ware...
# 1        UpGrad is an online higher education platform.
# ...

# %%
startup_2021['Amount($)'] = startup_2021['Amount($)'].replace('Undisclosed','np.nan', regex = True)

startup_2021['Amount($)'] = startup_2021['Amount($)'].replace('$undisclosed','np.nan', regex = True)

startup_2021['Amount($)'] = startup_2021['Amount($)'].replace('$Undisclosed','np.nan', regex = True)

startup_2021['Amount($)'] = startup_2021['Amount($)'].replace('nan','np.nan', regex = True)

startup_2021['Amount($)'] = startup_2021['Amount($)'].replace('Undislosed','np.nan', regex = True)

# %%
# converting to float datatype

#startup_2021['Amount($)']= pd.to_numeric(startup_2021['Amount($)'])

#startup_2021['Amount($)'] = startup_2021['Amount($)'].apply(float)

# %%
startup_2021.tail()
# Out:
#      Company/Brand  Founded HeadQuarter                 Sector  \
# 1204      Gigforce     2019    Gurugram  Staffing & Recruiting
# 1205        Vahdam     2015   New Delhi       Food & Beverages
# 1206  Leap Finance     2019   Bangalore     Financial Services
# 1207  CollegeDekho     2015    Gurugram                 EdTech
# 1208        WeRize     2019   Bangalore     Financial Services
#
#                                            What it does  \
# 1204                  A gig/on-demand staffing company.
# 1205  VAHDAM is among the world’s first vertically i...
# 1206  International education loans for high potenti...
# 1207  Collegedekho.com is Student’s Partner, Friend ...
# 1208  India’s first socially distributed full stack ...
#
#                            Founders                          Investor  \
# 1204    Chirag Mittal, Anirudh Syal                   Endiya Partners
# 1205                     Bala Sarda                          IIFL AMC
# ...

# %%
startup_2021['Amount($)'].unique()
# Out:
# array(['1200000', '120000000', '30000000', '51000000', '2000000',
#        '188000000', '200000', 'np.np.nan', '1000000', '3000000', '100000',
#        '700000', '9000000', '40000000', '49000000', '400000', '300000',
#        '25000000', '160000000', '150000', '1800000', '5000000', '850000',
#        '53000000', '500000', '1100000', '6000000', '800000', '10000000',
#        '21000000', '7500000', '26000000', '7400000', '1500000', '600000',
#        '800000000', '17000000', '3500000', '15000000', '215000000',
#        '2500000', '350000000', '5500000', '83000000', '110000000',
#        '500000000', '65000000', '150000000000', '300000000', '2200000',
#        '35000000', '140000000', '4000000', '13000000', 'np.nan',
#        '9500000', '8000000', 'Upsparks', '12000000', '1700000',
#        '150000000', '100000000', '225000000', '6700000', '1300000',
#        '20000000', '250000', '52000000', '3800000', '17500000',
#        '42000000', '2300000', '7000000', '450000000', '28000000',
# ...

# %%
startup_2021.duplicated().any()
# Out:
# True

# %%
startup_2021[1204:1209]
# Out:
#      Company/Brand  Founded HeadQuarter                 Sector  \
# 1204      Gigforce     2019    Gurugram  Staffing & Recruiting
# 1205        Vahdam     2015   New Delhi       Food & Beverages
# 1206  Leap Finance     2019   Bangalore     Financial Services
# 1207  CollegeDekho     2015    Gurugram                 EdTech
# 1208        WeRize     2019   Bangalore     Financial Services
#
#                                            What it does  \
# 1204                  A gig/on-demand staffing company.
# 1205  VAHDAM is among the world’s first vertically i...
# 1206  International education loans for high potenti...
# 1207  Collegedekho.com is Student’s Partner, Friend ...
# 1208  India’s first socially distributed full stack ...
#
#                            Founders                          Investor  \
# 1204    Chirag Mittal, Anirudh Syal                   Endiya Partners
# 1205                     Bala Sarda                          IIFL AMC
# ...

# %% [markdown]
# # IMPORTING THE CLEANED DATASETS FOR CONCATINATION

# %%
cleaned_2018= pd.read_csv('cleaned_2018.csv')

cleaned_2019= pd.read_csv('cleaned_2019.csv')

cleaned_2020= pd.read_csv('cleaned_2020.csv')

cleaned_2021= pd.read_csv('cleaned_2021.csv')

# %%
# Combining the datasets as one dataset

new_data = pd.concat([cleaned_2018,cleaned_2019,cleaned_2020,cleaned_2021], ignore_index=True)

new_data.column = ['Company/Brand','Founded','HeadQuarter','Sector','What it does',
                   'Founders','Investor','Amount($)','Stage','Year of Funding']

new_data
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_6480\1700365443.py:5: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   new_data.column = ['Company/Brand','Founded','HeadQuarter','Sector','What it does',
#         Company/Brand                 Sector         Stage HeadQuarter  \
# 0     TheCollegeFever        Brand Marketing          Seed   Bangalore
# 1     Happy Cow Dairy            Agriculture          Seed      Mumbai
# 2          MyLoanCare                 Credit      Series A     Gurgaon
# 3         PayMe India     Financial Services         Angel       Noida
# 4            Eunimart   E-Commerce Platforms          Seed   Hyderabad
# ...               ...                    ...           ...         ...
# 2872         Gigforce  Staffing & Recruiting  Pre-series A    Gurugram
# 2873           Vahdam       Food & Beverages      Series D   New Delhi
# ...

# %%
# DROPPING THE UNNAMED COLUMN


new_data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
new_data
# Out:
#         Company/Brand                 Sector         Stage HeadQuarter  \
# 0     TheCollegeFever        Brand Marketing          Seed   Bangalore
# 1     Happy Cow Dairy            Agriculture          Seed      Mumbai
# 2          MyLoanCare                 Credit      Series A     Gurgaon
# 3         PayMe India     Financial Services         Angel       Noida
# 4            Eunimart   E-Commerce Platforms          Seed   Hyderabad
# ...               ...                    ...           ...         ...
# 2872         Gigforce  Staffing & Recruiting  Pre-series A    Gurugram
# 2873           Vahdam       Food & Beverages      Series D   New Delhi
# 2874     Leap Finance     Financial Services      Series C   Bangalore
# 2875     CollegeDekho                 EdTech      Series B    Gurugram
# 2876           WeRize     Financial Services      Series A   Bangalore
#
#                                            What it does   Amount($)  \
# ...

# %%
new_data.head()
# Out:
#      Company/Brand                Sector     Stage HeadQuarter  \
# 0  TheCollegeFever       Brand Marketing      Seed   Bangalore
# 1  Happy Cow Dairy           Agriculture      Seed      Mumbai
# 2       MyLoanCare                Credit  Series A     Gurgaon
# 3      PayMe India    Financial Services     Angel       Noida
# 4         Eunimart  E-Commerce Platforms      Seed   Hyderabad
#
#                                         What it does  Amount($)  \
# 0  TheCollegeFever is a hub for fun, fiesta and f...   250000.0
# 1  A startup which aggregates milk from dairy far...   584000.0
# 2          Leading Online Loans Marketplace in India   949000.0
# 3  PayMe India is an innovative FinTech organizat...  2000000.0
# 4  Eunimart is a one stop solution for merchants ...        NaN
#
#    Year of Funding  Founded Founders Investor
# 0           2018.0      NaN      NaN      NaN
# 1           2018.0      NaN      NaN      NaN
# 2           2018.0      NaN      NaN      NaN
# ...

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2877 entries, 0 to 2876
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Company/Brand    2877 non-null   object
#  1   Sector           2877 non-null   object
#  2   Stage            2876 non-null   object
#  3   HeadQuarter      2783 non-null   object
#  4   What it does     2877 non-null   object
#  5   Amount($)        2727 non-null   float64
#  6   Year of Funding  2788 non-null   float64
#  7   Founded          2351 non-null   float64
#  8   Founders         2351 non-null   object
#  9   Investor         2289 non-null   object
# dtypes: float64(3), object(7)
# memory usage: 224.9+ KB

# %%
new_data.describe()
# Out:
#           Amount($)  Year of Funding      Founded
# count  2.727000e+03      2788.000000  2351.000000
# mean   1.108270e+08      2020.055595  2015.106536
# std    3.170203e+09         1.088542    41.783849
# min    0.000000e+00      2018.000000     0.000000
# 25%    8.000000e+05      2020.000000  2015.000000
# 50%    3.500000e+06      2020.000000  2016.000000
# 75%    2.300000e+07      2021.000000  2019.000000
# max    1.500000e+11      2021.000000  2021.000000

# %%
new_data.shape
# Out:
# (2877, 10)

# %%
new_data.isna().any()
# Out:
# Company/Brand      False
# Sector             False
# Stage               True
# HeadQuarter         True
# What it does       False
# Amount($)           True
# Year of Funding     True
# Founded             True
# Founders            True
# Investor            True
# dtype: bool

# %%
new_data.isna().sum()

# %%
new_data.columns

# %% [markdown]
# ### WE NEED TO DIVIDE OUR DATA INTO TWO DATATYPES, THIS IS HELP US DEAL WITH THE MISSING VALUES USING SIMPLEIMPUTER
#
# ### THE NUMERICAL DATA AND THE CATEGORICAL DATA

# %%
num_data = new_data.select_dtypes(exclude='object')

cat_data = new_data.select_dtypes(include='object')

# %%
num_data

# %%
num_cols = ['Amount($)','Year of Funding','Founded']

# %%
cat_data

# %%
cat_cols = ['Company/Brand','Sector','Stage','HeadQuarter','What it does','Founders','Investor']

# %%
# WE SHALL BE USING "MEAN" AND "MOST_FRQUENT"

num_imputer = SimpleImputer(strategy = 'mean').fit(new_data[num_cols])

cat_imputer = SimpleImputer(strategy = 'most_frequent').fit(new_data[cat_cols])

# %%
# APPLYING TRANSFORMATION

num_imputed = pd.DataFrame(num_imputer.transform(new_data[num_cols]), columns = num_cols)

cat_imputed = pd.DataFrame(cat_imputer.transform(new_data[cat_cols]), columns = cat_cols)

# %%
num_imputed

# %%
# splitting the "Founded" Column to leave only the years
num_imputed['Founded'] = num_imputed['Founded'].apply(str)

num_imputed['Founded'] = num_imputed['Founded'].str.split('.').str[0]

# converting to float datatype

num_imputed['Founded'] = pd.to_numeric(num_imputed['Founded'])

#num_imputed['Founded'] = num_imputed['Founded']'].apply(float)

# %%
num_imputed

# %%
# splitting the "Year of Funding" Column to leave only the years

num_imputed['Year of Funding'] = num_imputed['Year of Funding'].apply(str)

num_imputed['Year of Funding'] = num_imputed['Year of Funding'].str.split('.').str[0]

# converting to float datatype

num_imputed['Year of Funding'] = pd.to_numeric(num_imputed['Year of Funding'])

# %%
num_imputed

# %%
cat_imputed

# %%
# JOINING THE TO TWO DATASET BY CONCATINATION

cleaned_new_data = pd.concat([num_imputed,cat_imputed], axis = 1)

# %%
cleaned_new_data

# %%
# DROPPING FOUNDERS AND INVESTORS COLUMNS

#cleaned_new_data.drop('Founders', axis = 1, inplace = True)

cleaned_new_data

# %%
cleaned_new_data.drop('Investor', axis = 1, inplace = True)

# %%
cleaned_new_data

# %%
# Using the pd.set_option to take of the  Amount columns figures in exponential

#pd.options.display.float_format = '{:.0f}'.format

#pd.options('display.float_format', lambda x: '%.2f' % x)

pd.options.display.float_format = lambda x : '{:.0f}'.format(x) if round(x,0) == x else '{:,.2f}'.format(x)

# %%
# ANALYSING THE CLEANED NEW DATASET

cleaned_new_data.describe()

# %%
cleaned_new_data.isna().sum()

# %%
cleaned_new_data.info()

# %%
cleaned_new_data.head()

# %% [markdown]
# ### UNIVARIATE ANALYSIS

# %%
sns.distplot(cleaned_new_data.iloc[:50]['Year of Funding'], kde=False,color='black',bins=20)

#plt.show()

# %% [markdown]
# ### MULTIVARIATE ANALYSIS

# %% [markdown]
# ### We will try to see relations between continuous variables and the ‘Year of Funding’ column. To do that, we will plot a pair plot, with Hue as 'Year of Funding’.

# %%
sns.pairplot(cleaned_new_data.iloc[:10][['Amount($)','Year of Funding','Founded']],
            hue = 'Year of Funding')

# %% [markdown]
# # Re-Calling our Hypothesis and Analytical Questions

# %% [markdown]
# ###  HYPOTHESIS
#
# ### HO (Null): Year of Funding  is not dependent on the amount raised.
#
# ### H1(Alternative): Year of Funding  is dependent on the amount raised.
#
# ### ANALYTICAL QUESTIONS
#
# ### 1) What is the total amount raised by all the investors
#
# ### 2) Which sector has the highest amount invested.¶
#
# ### 3) Which year has the most start up founded.
#
# ### 4) Which Headquarters has the highest of funding.
#
# ### 5) Which Company has the highest amount invested on and what year?
#
# ### 6) What is the Maximum, Minimum and Average amount raised.

# %% [markdown]
# ## HYPOTHESIS TESTING

# %%
# OUR SIGNIFICANCE LEVEL IS 5%

# WE ARE USING T TEST

#perform two sample t-test

yr = cleaned_new_data['Year of Funding']
amt = cleaned_new_data['Amount($)']

t,p = stats.ttest_ind(a=yr, b=amt) 

print(f't-value: {t}')
print(f'p-value: {p}')

# %%
print("p-value for significance is: ", p)
if p<0.05:
    print("reject null hypothesis")
else:
    print("accept null hypothesis")

# %%
sns.histplot(data = cleaned_new_data.iloc[:10], x = 'Amount($)', hue = 'Year of Funding', kde = True )

# %% [markdown]
# ### Since the p-value of the test (0.0541) is equal to or greater than .05, we accept the null hypothesis.
#
# ### This means we have sufficient evidence to say that the Year of Funding is not dependant on the Amount raised.

# %% [markdown]
# ## ANALYSIS

# %% [markdown]
# ### 1) What is the total amount raised by all the investors

# %%
amount_total = cleaned_new_data['Amount($)'].sum()

print(f'The Total Amount Raised by all the investors is: {amount_total}')

# %%
#cleaned_new_data['Amount($)'].sum()

# %% [markdown]
# ### 2) Which sectors has the highest amount invested.

# %%
Sectors_with_highest_amount = cleaned_new_data.groupby('Sector')['Amount($)'].sum().reset_index()

Sectors_with_highest_amount

# %%
Sectors_with_highest_amount.sort_values(by="Amount($)", ascending= False)

Sectors_with_highest_amount.head(10)

# %%
plt.figure(figsize=(12,10))

sns.barplot(y='Sector', x='Amount($)', data=Sectors_with_highest_amount.iloc[:10])

plt.title('Sectors with highest amount invested', fontsize=20)

plt.ylabel('Sector')

plt.xlabel('Amount($)')

plt.show()

# %%
file_name = "Sectors_with_highest_amount.csv"

Sectors_with_highest_amount.to_csv(file_name)

# %% [markdown]
# ### FinTech has the most amount, followed by EdTech and Financial Services

# %% [markdown]
# ### 3) Which year has the most start up founded.

# %%
year_most_funded = cleaned_new_data.groupby('Year of Funding')['Amount($)'].sum().reset_index()

year_most_funded

# %%
 Year_most_funded = year_most_funded.sort_values(by="Amount($)", ascending= False)

 Year_most_funded

# %%
plt.figure(figsize=(10,10))

sns.barplot(y='Year of Funding', x='Amount($)', data=Year_most_funded)

plt.title('Year_Most_Funded', fontsize=20)

plt.ylabel('Year of Funding')

plt.xlabel('Amount($)')

plt.show()

# %%
file_name = "Year_most_funded.csv"

Year_most_funded.to_csv(file_name)

# %% [markdown]
# ### 4) Which Headquarters has the highest  of funding.

# %%
Hq_with_highest_amount = cleaned_new_data.groupby('HeadQuarter')['Amount($)'].sum().reset_index()

# %%
Hqters_with_highest_amount = Hq_with_highest_amount.sort_values(by="Amount($)", ascending= False)

Hqters_with_highest_amount.head(15)

# %%
plt.figure(figsize=(10,10))

sns.barplot(y='HeadQuarter', x='Amount($)', data=Hqters_with_highest_amount.iloc[:10])

plt.title('Headquarters That received the highest Amount', fontsize=20)

plt.ylabel('HeadQuarter')

plt.xlabel('Amount($)')

plt.show()

# %%
file_name = "Hqters_with_highest_amount.csv"

Hqters_with_highest_amount.to_csv(file_name)

# %% [markdown]
# ### 5) Which Company has the highest amount invested on and what year?

# %%
comp_with_most_amt_invested_with_year = cleaned_new_data.groupby('Company/Brand')['Amount($)','Year of Funding'].sum().reset_index()

Coy_with_most_amt_invested_with_year = comp_with_most_amt_invested_with_year.sort_values(by="Amount($)", ascending= False)

Coy_with_most_amt_invested_with_year

# %%
Coy_with_most_amt_invested_with_year.head(4)

# %%
plt.figure(figsize=(10,10))

sns.barplot(y='Company/Brand', x='Amount($)', data = Coy_with_most_amt_invested_with_year.iloc[:10])

plt.title('Company/Brand That received the highest Amount', fontsize=20)

plt.ylabel('Company/Brand')

plt.xlabel('Amount($)')

plt.show()

# %%
file_name = "Coy_with_most_amt_invested_with_year.csv"

Coy_with_most_amt_invested_with_year.to_csv(file_name)

# %%
cleaned_new_data

# %%
file_name = "cleaned_new_data.csv"

cleaned_new_data.to_csv(file_name)

# %%
#Coy_with_most_amt_invested_with_year.iloc[:10]
